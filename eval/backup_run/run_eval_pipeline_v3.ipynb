# %% [markdown]
# # Pipeline de avaliação — multi-modelo × multi-edital
#
# Roda o agente em todas as combinações `(modelo, edital)` definidas, salva um xlsx
# por combinação em `resultados/` e exibe sumário consolidado.
#
# **Proteções contra desastre:**
# 1. Validação de preços antes de rodar (pega `PRECOS` faltando).
# 2. Smoke test: 1 pergunta por combinação antes de soltar as 50.
# 3. Limite de gasto por combinação — corta no meio se estourar.
# 4. Salvamento garantido em qualquer erro: o que foi medido até a falha vai pro xlsx.
# 5. Sumário final lista sucessos, parciais e falhas separadamente.

# %%
import os, sys, time, glob
from pathlib import Path
from datetime import datetime

ROOT = Path.cwd().parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

import warnings
warnings.filterwarnings("ignore")
os.environ["TOKENIZERS_PARALLELISM"] = "false"

import pandas as pd
from dotenv import load_dotenv
load_dotenv(ROOT / ".env")

from agent.agent import build_agent, ask
from langchain_core.callbacks import BaseCallbackHandler

print(f"cwd:  {Path.cwd()}")
print(f"root: {ROOT}")
# Out:
# cwd:  /home/julio/Documentos/tcc_GENAI/v8/edital-assistant/evals
# root: /home/julio/Documentos/tcc_GENAI/v8/edital-assistant

# %% [markdown]
# ## TokenTracker — captura tokens + cache

# %%
class TokenTracker(BaseCallbackHandler):
    def __init__(self):
        self.reset()

    def reset(self):
        self.input_tokens = 0
        self.output_tokens = 0
        self.cache_read_tokens = 0
        self.cache_write_tokens = 0
        self.n_calls = 0

    def on_llm_end(self, response, **kwargs):
        self.n_calls += 1

        usage = (getattr(response, "llm_output", None) or {}).get("token_usage") or {}
        if usage:
            self.input_tokens  += usage.get("prompt_tokens", 0) or 0
            self.output_tokens += usage.get("completion_tokens", 0) or 0
            ds_hit = usage.get("prompt_cache_hit_tokens") or 0
            details = usage.get("prompt_tokens_details") or {}
            oai_hit = details.get("cached_tokens") or 0
            self.cache_read_tokens += max(ds_hit, oai_hit)
            return

        for gen_list in response.generations:
            for gen in gen_list:
                msg = getattr(gen, "message", None)
                um = getattr(msg, "usage_metadata", None) if msg else None
                if um:
                    self.input_tokens  += um.get("input_tokens", 0) or 0
                    self.output_tokens += um.get("output_tokens", 0) or 0
                    details = um.get("input_token_details") or {}
                    self.cache_read_tokens  += details.get("cache_read", 0) or 0
                    self.cache_write_tokens += details.get("cache_creation", 0) or 0
                    break

# %% [markdown]
# ## Configuração
#
# Comente os índices que não quer rodar. `LIMITE_USD_POR_COMBO` é teto sobre estimativa
# pessimista (sem cache) — real será sempre menor.

# %%
MODELOS = [
    ## (provider, modelo)
    # ("openai",    "gpt-4o-mini"),
    # ("deepseek",  "deepseek-v4-flash"),
    # ("openai",    "gpt-5.4-mini"),
    # ("deepseek",  "deepseek-v4-pro"),
    # ("anthropic", "claude-haiku-4-5"),
    # --- modelos caros — descomente quando for rodar ---
    ("openai",    "gpt-5.4"),
    ("anthropic", "claude-sonnet-4-6"),
    ("anthropic", "claude-opus-4-7"),
    ("openai",    "gpt-5.5"),
]

EDITAIS = [
    ("bndes",     1),
    ("cvm",       2),
    ("petrobras", 3),
]

# USD por 1M tokens. Ordem: (input_miss, input_cached, output).
PRECOS = {
    "openai/gpt-4o-mini":             (0.15,  0.075,  0.60),
    "openai/gpt-5.4-mini":            (0.25,  0.125,  2.00),
    "openai/gpt-5.4":                 (1.25,  0.625, 10.00),
    "openai/gpt-5.5":                 (5.00,  2.500, 30.00),
    "deepseek/deepseek-v4-flash":     (0.14,  0.028,  0.28),
    "deepseek/deepseek-v4-pro":       (1.74,  0.145,  3.48),
    "anthropic/claude-haiku-4-5":     (1.00,  1.000,  5.00),
    "anthropic/claude-sonnet-4-6":    (3.00,  3.000, 15.00),
    "anthropic/claude-opus-4-7":      (5.00,  5.000, 25.00),
}

LIMITE_USD_POR_COMBO = 20.00

PERGUNTAS_DIR  = Path("perguntas")
RESULTADOS_DIR = Path("resultados")
RESULTADOS_DIR.mkdir(exist_ok=True)

print(f"Modelos ativos:        {len(MODELOS)}")
print(f"Editais:               {len(EDITAIS)}")
print(f"Total de combinações:  {len(MODELOS) * len(EDITAIS)}")
print(f"Teto por combinação:   ${LIMITE_USD_POR_COMBO}")
# Out:
# Modelos ativos:        4
# Editais:               3
# Total de combinações:  12
# Teto por combinação:   $20.0

# %% [markdown]
# ## Validação 1 — preços (gratuita, não chama API)

# %%
faltando = [f"{p}/{m}" for p, m in MODELOS if f"{p}/{m}" not in PRECOS]
if faltando:
    raise RuntimeError(f"Modelos sem preço em PRECOS: {faltando}")
print(f"OK — todos os {len(MODELOS)} modelos têm preço configurado.")
# Out:
# OK — todos os 4 modelos têm preço configurado.

# %% [markdown]
# ## Helpers

# %%
def slug(modelo: str) -> str:
    return modelo.replace("/", "_").replace(":", "_")


def custo_estimado(in_tok: int, out_tok: int, p_in: float, p_out: float) -> float:
    """Teto: trata todo input como cache miss."""
    return in_tok / 1_000_000 * p_in + out_tok / 1_000_000 * p_out


def custo_real(in_tok: int, out_tok: int, cache_read: int,
               p_in: float, p_in_cached: float, p_out: float) -> float:
    miss = max(in_tok - cache_read, 0)
    return (
        miss / 1_000_000 * p_in
        + cache_read / 1_000_000 * p_in_cached
        + out_tok / 1_000_000 * p_out
    )


def salvar_xlsx(provider, modelo, edital_nome, resultados, sufixo=""):
    df_r = pd.DataFrame(resultados)
    ts = datetime.now().strftime("%Y%m%d_%H%M%S")
    nome = f"{edital_nome}__{provider}__{slug(modelo)}__{ts}{sufixo}.xlsx"
    arq = RESULTADOS_DIR / nome
    df_r.to_excel(arq, index=False)
    return arq


def apagar_antigos(provider, modelo, edital_nome):
    padrao = str(RESULTADOS_DIR / f"{edital_nome}__{provider}__{slug(modelo)}__*.xlsx")
    n = 0
    for antigo in glob.glob(padrao):
        Path(antigo).unlink()
        n += 1
    return n

# %%
def rodar_combo(provider, modelo, edital_nome, edital_id, limite_usd=LIMITE_USD_POR_COMBO):
    """Roda N perguntas. Retorna (xlsx_path, erro_fatal_ou_None).
    
    Erros em perguntas individuais vão pra coluna `erro` e a combinação continua.
    Estouro de orçamento ou erro fora do loop interrompem e salvam parcial."""
    chave = f"{provider}/{modelo}"
    p_in, p_in_cached, p_out = PRECOS[chave]

    arq_perguntas = PERGUNTAS_DIR / f"{edital_nome}.xlsx"
    df_q = pd.read_excel(arq_perguntas)
    df_q = df_q.dropna(subset=["pergunta"])
    df_q = df_q[df_q["pergunta"].str.strip() != ""].reset_index(drop=True)

    agente = build_agent(provider=provider, model=modelo)
    tracker = TokenTracker()
    agente.llm       = agente.llm.with_config(callbacks=[tracker])
    agente.llm_check = agente.llm_check.with_config(callbacks=[tracker])

    resultados = []
    custo_estim_acum = 0.0
    erro_fatal = None

    for i, row in df_q.iterrows():
        pergunta = row["pergunta"]
        t0 = time.time()
        erro, resposta = None, None

        tracker.reset()
        try:
            resposta = ask(agent=agente, question=pergunta, chat_history=[], edital_id_ativo=edital_id)
        except Exception as e:
            erro = str(e)

        in_tok     = tracker.input_tokens
        out_tok    = tracker.output_tokens
        cache_read = tracker.cache_read_tokens
        n_calls    = tracker.n_calls
        latencia   = round(time.time() - t0, 2)

        c_estim = custo_estimado(in_tok, out_tok, p_in, p_out)
        c_real  = custo_real(in_tok, out_tok, cache_read, p_in, p_in_cached, p_out)
        custo_estim_acum += c_estim

        resultados.append({
            "id":                row["id"],
            "categoria":         row.get("categoria", ""),
            "pergunta":          pergunta,
            "resposta":          resposta,
            "input_tokens":      in_tok,
            "output_tokens":     out_tok,
            "total_tokens":      in_tok + out_tok,
            "cache_read_tokens": cache_read,
            "cache_miss_tokens": max(in_tok - cache_read, 0),
            "n_invocacoes":      n_calls,
            "custo_usd":         round(c_estim, 6),
            "custo_real_usd":    round(c_real, 6),
            "latencia_s":        latencia,
            "erro":              erro,
        })

        flag = "ERRO" if erro else "ok"
        cache_pct = (cache_read / in_tok * 100) if in_tok else 0
        print(f"      [{i+1:>2}/{len(df_q)}] {flag:>4}  {latencia:>5}s  "
              f"calls={n_calls}  in={in_tok:>5} (cache {cache_pct:>4.0f}%)  "
              f"out={out_tok:>4}  acum=${custo_estim_acum:.4f}")

        if custo_estim_acum > limite_usd:
            erro_fatal = f"Estouro na pergunta {i+1}: ${custo_estim_acum:.4f} > ${limite_usd}"
            break

    sufixo = "__PARCIAL" if erro_fatal else ""
    arq = salvar_xlsx(provider, modelo, edital_nome, resultados, sufixo) if resultados else None
    return arq, erro_fatal

# %% [markdown]
# ## Validação 2 — smoke test
#
# Uma pergunta por combinação. Se algum modelo tiver armadilha (thinking mode default,
# credencial faltando, formato de tool diferente), explode aqui em vez de em 50
# perguntas. Se qualquer combo falhar, **a célula levanta erro** e o loop principal
# não roda.

# %%
print("=== SMOKE TEST ===\n")

smoke_falhas = []

for provider, modelo in MODELOS:
    for edital_nome, edital_id in EDITAIS:
        print(f"  [test] {provider}/{modelo} × {edital_nome} ... ", end="", flush=True)
        try:
            agente = build_agent(provider=provider, model=modelo)
            tracker = TokenTracker()
            agente.llm       = agente.llm.with_config(callbacks=[tracker])
            agente.llm_check = agente.llm_check.with_config(callbacks=[tracker])

            resp = ask(agent=agente, question="Qual o salário inicial?",
                       chat_history=[], edital_id_ativo=edital_id)

            if not resp or len(resp.strip()) < 20:
                raise ValueError(f"resposta vazia/curta: {resp!r}")
            print(f"ok ({tracker.input_tokens} in / {tracker.output_tokens} out / {tracker.n_calls} calls)")
        except Exception as e:
            smoke_falhas.append(f"{provider}/{modelo} × {edital_nome}: {e}")
            print(f"FALHOU\n           {e}")

if smoke_falhas:
    raise RuntimeError(
        f"\n{len(smoke_falhas)} combinação(ões) falhou(ram). Corrija ou comente:\n  - " +
        "\n  - ".join(smoke_falhas)
    )

print(f"\nTodas as {len(MODELOS) * len(EDITAIS)} combinações passaram.")
# Out:
# === SMOKE TEST ===
#
#   [test] openai/gpt-5.4 × bndes ... Carregando BGE-M3 (primeira vez pode demorar)...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100%|██████████| 391/391 [00:00<00:00, 45188.27it/s]
# ok (5066 in / 75 out / 2 calls)
#   [test] openai/gpt-5.4 × cvm ... ok (4596 in / 72 out / 2 calls)
#   [test] openai/gpt-5.4 × petrobras ... ok (4548 in / 110 out / 2 calls)
#   [test] anthropic/claude-sonnet-4-6 × bndes ... ok (11344 in / 260 out / 2 calls)
#   [test] anthropic/claude-sonnet-4-6 × cvm ... ok (10036 in / 193 out / 2 calls)
#   [test] anthropic/claude-sonnet-4-6 × petrobras ... ok (10856 in / 246 out / 2 calls)
#   [test] anthropic/claude-opus-4-7 × bndes ... ok (14313 in / 274 out / 2 calls)
#   [test] anthropic/claude-opus-4-7 × cvm ... ok (13608 in / 212 out / 2 calls)
#   [test] anthropic/claude-opus-4-7 × petrobras ... ok (14192 in / 284 out / 2 calls)
#   [test] openai/gpt-5.5 × bndes ... ok (7262 in / 117 out / 2 calls)
#   [test] openai/gpt-5.5 × cvm ... ok (4604 in / 102 out / 2 calls)
#   [test] openai/gpt-5.5 × petrobras ... ok (6596 in / 114 out / 2 calls)
#
# Todas as 12 combinações passaram.

# %% [markdown]
# ## Pipeline principal
#
# Sobrescreve xlsx antigos. Erro numa combinação não para as outras. Sumário
# no fim separa sucessos, parciais (estouro) e falhas.

# %%
sucessos, parciais, falhas = [], [], []

for provider, modelo in MODELOS:
    for edital_nome, edital_id in EDITAIS:
        n = apagar_antigos(provider, modelo, edital_nome)
        if n:
            print(f"\n[del]  {n} xlsx antigo(s) de {provider}/{modelo} × {edital_nome}")
        print(f"\n[run]  {provider}/{modelo} × {edital_nome} (id={edital_id})")

        try:
            arq, erro_fatal = rodar_combo(provider, modelo, edital_nome, edital_id)
        except Exception as e:
            falhas.append((provider, modelo, edital_nome, str(e)))
            print(f"       ✗ FALHOU antes do xlsx: {e}")
            continue

        if erro_fatal:
            parciais.append((provider, modelo, edital_nome, arq, erro_fatal))
            print(f"       ⚠ PARCIAL — {erro_fatal}\n         salvo em {arq.name}")
        else:
            sucessos.append((provider, modelo, edital_nome, arq))
            print(f"       ✓ ok — salvo em {arq.name}")

print("\n" + "=" * 60)
print("=== SUMÁRIO ===")
print("=" * 60)
print(f"\n✓ Sucessos: {len(sucessos)}")
for p, m, e, a in sucessos:
    print(f"    {p}/{m} × {e}  →  {a.name}")
print(f"\n⚠ Parciais (estouro de orçamento): {len(parciais)}")
for p, m, e, a, err in parciais:
    print(f"    {p}/{m} × {e}  →  {a.name}\n        {err}")
print(f"\n✗ Falhas: {len(falhas)}")
for p, m, e, err in falhas:
    print(f"    {p}/{m} × {e}\n        {err}")
# Out:
# [run]  openai/gpt-5.4 × bndes (id=1)
#       [ 1/50]   ok   3.52s  calls=2  in= 6310 (cache   24%)  out=  82  acum=$0.0087
#       [ 2/50]   ok   4.45s  calls=2  in= 6193 (cache   25%)  out=  75  acum=$0.0172
#       [ 3/50]   ok   5.22s  calls=3  in= 9734 (cache   46%)  out= 134  acum=$0.0307
#       [ 4/50]   ok   4.92s  calls=2  in= 5535 (cache   30%)  out= 204  acum=$0.0397
#       [ 5/50]   ok   3.48s  calls=2  in= 6417 (cache   24%)  out= 109  acum=$0.0488
#       [ 6/50]   ok   4.91s  calls=2  in= 7012 (cache   22%)  out= 149  acum=$0.0590
#       [ 7/50]   ok   3.48s  calls=2  in= 6325 (cache   24%)  out=  99  acum=$0.0679
#       [ 8/50]   ok   3.17s  calls=2  in= 5405 (cache   28%)  out=  87  acum=$0.0756
#       [ 9/50]   ok   6.15s  calls=3  in=12096 (cache   43%)  out= 197  acum=$0.0926
#       [10/50]   ok   8.49s  calls=3  in=12407 (cache   42%)  out= 254  acum=$0.1107
#       [11/50]   ok   3.82s  calls=2  in= 5492 (cache   28%)  out= 123  acum=$0.1188
#       [12/50]   ok   5.04s  calls=2  in= 6484 (cache   47%)  out= 165  acum=$0.1285
#       [13/50]   ok   5.28s  calls=2  in= 5666 (cache   27%)  out= 117  acum=$0.1368
#       [14/50]   ok   3.76s  calls=2  in= 6282 (cache   24%)  out= 131  acum=$0.1460
#       [15/50]   ok  11.19s  calls=6  in=38666 (cache   64%)  out= 260  acum=$0.1969
#       [16/50]   ok   5.53s  calls=2  in= 6240 (cache   25%)  out= 108  acum=$0.2058
#       [17/50]   ok   9.02s  calls=3  in=13553 (cache   57%)  out= 381  acum=$0.2265
#       [18/50]   ok   4.09s  calls=2  in= 4741 (cache   35%)  out= 147  acum=$0.2339
#       [19/50]   ok   3.29s  calls=2  in= 6302 (cache   24%)  out= 128  acum=$0.2431
#       [20/50]   ok   6.64s  calls=2  in= 5924 (cache   54%)  out= 135  acum=$0.2518
#       [21/50]   ok   6.35s  calls=2  in= 6849 (cache   22%)  out= 297  acum=$0.2634
#       [22/50]   ok   6.55s  calls=2  in= 6252 (cache   25%)  out= 274  acum=$0.2739
#       [23/50]   ok   3.69s  calls=2  in= 5727 (cache   27%)  out= 139  acum=$0.2825
#       [24/50]   ok   4.53s  calls=2  in= 5375 (cache   29%)  out= 153  acum=$0.2907
#       [25/50]   ok   3.35s  calls=2  in= 5000 (cache   31%)  out= 102  acum=$0.2980
#       [26/50]   ok  11.26s  calls=6  in=40022 (cache   76%)  out= 310  acum=$0.3511
#       [27/50]   ok   9.42s  calls=4  in=20125 (cache   62%)  out= 263  acum=$0.3789
#       [28/50]   ok   4.71s  calls=2  in= 5370 (cache   29%)  out= 181  acum=$0.3874
#       [29/50]   ok   3.28s  calls=2  in= 6206 (cache   50%)  out=  99  acum=$0.3962
#       [30/50]   ok   5.43s  calls=2  in= 6546 (cache   47%)  out= 234  acum=$0.4067
#       [31/50]   ok    4.4s  calls=2  in= 5809 (cache   26%)  out= 174  acum=$0.4157
#       [32/50]   ok   4.24s  calls=2  in= 6538 (cache   23%)  out= 163  acum=$0.4255
#       [33/50]   ok   3.44s  calls=2  in= 5696 (cache   54%)  out= 132  acum=$0.4339
#       [34/50]   ok   3.18s  calls=2  in= 4998 (cache   64%)  out=  96  acum=$0.4411
#       [35/50]   ok   4.33s  calls=2  in= 6393 (cache   48%)  out= 158  acum=$0.4507
#       [36/50]   ok   4.67s  calls=2  in= 6802 (cache    0%)  out= 190  acum=$0.4611
#       [37/50]   ok   5.64s  calls=2  in= 5913 (cache   28%)  out= 259  acum=$0.4711
#       [38/50]   ok    4.4s  calls=2  in= 5995 (cache   26%)  out= 172  acum=$0.4803
#       [39/50]   ok   5.63s  calls=2  in= 6672 (cache   23%)  out= 193  acum=$0.4906
#       [40/50]   ok   9.71s  calls=2  in= 6047 (cache   28%)  out= 190  acum=$0.5000
#       [41/50]   ok   9.03s  calls=2  in= 6761 (cache   25%)  out= 407  acum=$0.5126
#       [42/50]   ok   2.79s  calls=2  in= 7088 (cache   22%)  out=  77  acum=$0.5222
#       [43/50]   ok   3.45s  calls=2  in= 5836 (cache   26%)  out=  97  acum=$0.5305
#       [44/50]   ok   4.89s  calls=2  in= 7730 (cache   20%)  out= 156  acum=$0.5417
#       [45/50]   ok   9.25s  calls=3  in=13124 (cache   44%)  out= 440  acum=$0.5625
#       [46/50]   ok   3.89s  calls=2  in= 6756 (cache    0%)  out= 137  acum=$0.5723
#       [47/50]   ok    4.4s  calls=2  in= 5688 (cache   56%)  out= 155  acum=$0.5810
#       [48/50]   ok   3.79s  calls=2  in= 6610 (cache   25%)  out=  90  acum=$0.5901
#       [49/50]   ok   7.17s  calls=2  in= 5998 (cache    0%)  out= 306  acum=$0.6007
#       [50/50]   ok   4.91s  calls=2  in= 5730 (cache   29%)  out= 249  acum=$0.6103
#        ✓ ok — salvo em bndes__openai__gpt-5.4__20260430_143844.xlsx
#
# [run]  openai/gpt-5.4 × cvm (id=2)
#       [ 1/50]   ok   5.65s  calls=2  in= 5796 (cache   27%)  out= 149  acum=$0.0087
#       [ 2/50]   ok   3.38s  calls=2  in= 5040 (cache   30%)  out=  76  acum=$0.0158
#       [ 3/50]   ok   3.07s  calls=2  in= 5990 (cache   26%)  out=  85  acum=$0.0241
#       [ 4/50]   ok   4.71s  calls=2  in= 5380 (cache   29%)  out= 175  acum=$0.0326
#       [ 5/50]   ok   3.27s  calls=2  in= 5720 (cache   27%)  out= 128  acum=$0.0410
#       [ 6/50]   ok   7.07s  calls=2  in= 5502 (cache   28%)  out= 218  acum=$0.0501
#       [ 7/50]   ok   3.27s  calls=2  in= 5477 (cache    0%)  out= 101  acum=$0.0580
#       [ 8/50]   ok   3.89s  calls=2  in= 6055 (cache   25%)  out= 154  acum=$0.0671
#       [ 9/50]   ok   4.02s  calls=2  in= 5459 (cache    0%)  out= 129  acum=$0.0752
#       [10/50]   ok   4.89s  calls=2  in= 5439 (cache   28%)  out= 102  acum=$0.0830
#       [11/50]   ok   3.48s  calls=2  in= 4586 (cache   33%)  out=  82  acum=$0.0895
#       [12/50]   ok   3.33s  calls=2  in= 5943 (cache   28%)  out= 105  acum=$0.0980
#       [13/50]   ok   3.43s  calls=2  in= 5646 (cache   27%)  out=  97  acum=$0.1061
#       [14/50]   ok   3.79s  calls=2  in= 6296 (cache   24%)  out= 133  acum=$0.1153
#       [15/50]   ok   2.87s  calls=2  in= 5642 (cache   27%)  out=  83  acum=$0.1231
#       [16/50]   ok   6.04s  calls=3  in=12565 (cache   44%)  out= 226  acum=$0.1411
#       [17/50]   ok  15.59s  calls=5  in=23802 (cache   69%)  out= 412  acum=$0.1750
#       [18/50]   ok    5.6s  calls=2  in= 5818 (cache   29%)  out= 158  acum=$0.1838
#       [19/50]   ok   3.69s  calls=2  in= 4636 (cache   36%)  out= 123  acum=$0.1909
#       [20/50]   ok   3.17s  calls=2  in= 6085 (cache   25%)  out= 106  acum=$0.1995
#       [21/50]   ok    4.4s  calls=2  in= 5901 (cache   26%)  out= 197  acum=$0.2089
#       [22/50]   ok   8.37s  calls=2  in= 5402 (cache   28%)  out= 233  acum=$0.2179
#       [23/50]   ok   3.47s  calls=2  in= 6214 (cache   25%)  out= 127  acum=$0.2270
#       [24/50]   ok   5.17s  calls=2  in= 5210 (cache   32%)  out= 196  acum=$0.2355
#       [25/50]   ok  13.09s  calls=5  in=26972 (cache   69%)  out= 261  acum=$0.2718
#       [26/50]   ok  32.72s  calls=6  in=37277 (cache   66%)  out= 355  acum=$0.3219
#       [27/50]   ok    7.0s  calls=3  in=13994 (cache   34%)  out= 193  acum=$0.3413
#       [28/50]   ok   6.73s  calls=2  in= 6450 (cache   26%)  out= 206  acum=$0.3515
#       [29/50]   ok   8.63s  calls=3  in=13805 (cache   45%)  out= 232  acum=$0.3710
#       [30/50]   ok   8.09s  calls=2  in= 5932 (cache    0%)  out= 276  acum=$0.3812
#       [31/50]   ok    4.4s  calls=2  in= 5532 (cache   28%)  out= 109  acum=$0.3892
#       [32/50]   ok    4.5s  calls=2  in= 5726 (cache   29%)  out= 169  acum=$0.3981
#       [33/50]   ok    4.3s  calls=2  in= 5747 (cache   27%)  out= 165  acum=$0.4069
#       [34/50]   ok   4.11s  calls=2  in= 5377 (cache   29%)  out=  84  acum=$0.4145
#       [35/50]   ok   4.18s  calls=2  in= 5919 (cache   52%)  out= 164  acum=$0.4235
#       [36/50]   ok   5.73s  calls=2  in= 5716 (cache   27%)  out= 190  acum=$0.4326
#       [37/50]   ok  11.99s  calls=2  in= 6990 (cache   24%)  out= 212  acum=$0.4434
#       [38/50]   ok    4.5s  calls=2  in= 5930 (cache    0%)  out= 146  acum=$0.4523
#       [39/50]   ok   6.25s  calls=2  in= 5584 (cache   30%)  out= 165  acum=$0.4609
#       [40/50]   ok    4.2s  calls=2  in= 5934 (cache   26%)  out= 144  acum=$0.4698
#       [41/50]   ok   7.26s  calls=3  in=14690 (cache   46%)  out= 301  acum=$0.4911
#       [42/50]   ok   4.18s  calls=2  in= 5318 (cache   29%)  out=  94  acum=$0.4987
#       [43/50]   ok    3.3s  calls=2  in= 5480 (cache   28%)  out=  91  acum=$0.5065
#       [44/50]   ok   2.97s  calls=2  in= 5327 (cache   58%)  out= 109  acum=$0.5142
#       [45/50]   ok  12.29s  calls=4  in=25325 (cache   63%)  out= 536  acum=$0.5513
#       [46/50]   ok   5.43s  calls=2  in= 5973 (cache   26%)  out= 112  acum=$0.5598
#       [47/50]   ok   4.42s  calls=2  in= 5815 (cache   55%)  out= 205  acum=$0.5692
#       [48/50]   ok   4.43s  calls=2  in= 5032 (cache   31%)  out= 146  acum=$0.5769
#       [49/50]   ok   6.81s  calls=2  in= 5051 (cache   61%)  out= 300  acum=$0.5862
#       [50/50]   ok   5.53s  calls=2  in= 5884 (cache   54%)  out= 242  acum=$0.5960
#        ✓ ok — salvo em cvm__openai__gpt-5.4__20260430_144346.xlsx
#
# [run]  openai/gpt-5.4 × petrobras (id=3)
#       [ 1/50]   ok   6.81s  calls=4  in=16517 (cache   62%)  out= 158  acum=$0.0222
#       [ 2/50]   ok   5.12s  calls=2  in= 4771 (cache   32%)  out=  71  acum=$0.0289
#       [ 3/50]   ok   5.02s  calls=2  in= 5615 (cache   27%)  out=  90  acum=$0.0368
#       [ 4/50]   ok   3.95s  calls=2  in= 5948 (cache   26%)  out= 158  acum=$0.0458
#       [ 5/50]   ok   3.54s  calls=2  in= 6847 (cache   22%)  out= 131  acum=$0.0557
#       [ 6/50]   ok    4.5s  calls=2  in= 5467 (cache   28%)  out= 139  acum=$0.0639
#       [ 7/50]   ok   3.38s  calls=2  in= 6532 (cache   24%)  out= 115  acum=$0.0732
#       [ 8/50]   ok   3.38s  calls=2  in= 5366 (cache   29%)  out= 108  acum=$0.0810
#       [ 9/50]   ok   5.63s  calls=2  in= 5549 (cache    0%)  out= 194  acum=$0.0899
#       [10/50]   ok   3.53s  calls=2  in= 5430 (cache   28%)  out= 143  acum=$0.0981
#       [11/50]   ok    4.1s  calls=2  in= 4898 (cache   31%)  out= 133  acum=$0.1056
#       [12/50]   ok   5.48s  calls=2  in= 6189 (cache   25%)  out= 191  acum=$0.1152
#       [13/50]   ok   2.98s  calls=2  in= 5584 (cache   28%)  out= 103  acum=$0.1232
#       [14/50]   ok   6.18s  calls=2  in= 5571 (cache   28%)  out= 157  acum=$0.1318
#       [15/50]   ok  11.51s  calls=6  in=46738 (cache   71%)  out= 234  acum=$0.1925
#       [16/50]   ok   7.59s  calls=2  in= 5683 (cache    0%)  out= 131  acum=$0.2009
#       [17/50]   ok   9.91s  calls=3  in=13847 (cache   43%)  out= 362  acum=$0.2219
#       [18/50]   ok   5.27s  calls=2  in= 5367 (cache   29%)  out= 171  acum=$0.2303
#       [19/50]   ok    3.9s  calls=2  in= 5880 (cache   28%)  out= 154  acum=$0.2392
#       [20/50]   ok   3.04s  calls=2  in= 6017 (cache   26%)  out= 119  acum=$0.2479
#       [21/50]   ok   5.33s  calls=2  in= 5296 (cache   29%)  out= 233  acum=$0.2568
#       [22/50]   ok   6.24s  calls=2  in= 5747 (cache   27%)  out= 358  acum=$0.2676
#       [23/50]   ok    4.1s  calls=2  in= 4625 (cache   33%)  out= 152  acum=$0.2749
#       [24/50]   ok   3.89s  calls=2  in= 5669 (cache    0%)  out= 139  acum=$0.2834
#       [25/50]   ok   9.22s  calls=5  in=26299 (cache   72%)  out= 256  acum=$0.3188
#       [26/50]   ok    4.4s  calls=2  in= 6444 (cache    0%)  out= 151  acum=$0.3284
#       [27/50]   ok   3.89s  calls=2  in= 5522 (cache   58%)  out= 137  acum=$0.3367
#       [28/50]   ok   7.58s  calls=3  in=13912 (cache   12%)  out= 316  acum=$0.3572
#       [29/50]   ok    8.6s  calls=2  in= 5290 (cache    0%)  out= 212  acum=$0.3659
#       [30/50]   ok    4.0s  calls=2  in= 6145 (cache    0%)  out= 182  acum=$0.3754
#       [31/50]   ok    8.3s  calls=2  in= 5771 (cache   27%)  out= 191  acum=$0.3846
#       [32/50]   ok   3.36s  calls=2  in= 5463 (cache   28%)  out= 137  acum=$0.3928
#       [33/50]   ok   5.32s  calls=2  in= 4747 (cache   32%)  out=  74  acum=$0.3994
#       [34/50]   ok   3.29s  calls=2  in= 5359 (cache   29%)  out=  93  acum=$0.4071
#       [35/50]   ok   3.79s  calls=2  in= 6586 (cache   23%)  out= 122  acum=$0.4165
#       [36/50]   ok   5.12s  calls=2  in= 6578 (cache   23%)  out= 138  acum=$0.4261
#       [37/50]   ok    6.5s  calls=2  in= 6373 (cache   26%)  out= 285  acum=$0.4369
#       [38/50]   ok   5.47s  calls=2  in= 6327 (cache    0%)  out= 152  acum=$0.4464
#       [39/50]   ok   6.35s  calls=2  in= 5698 (cache    0%)  out= 179  acum=$0.4553
#       [40/50]   ok   5.22s  calls=2  in= 6163 (cache    0%)  out= 148  acum=$0.4645
#       [41/50]   ok   6.55s  calls=2  in= 6087 (cache   27%)  out= 196  acum=$0.4740
#       [42/50]   ok   7.84s  calls=4  in=21317 (cache   60%)  out= 177  acum=$0.5024
#       [43/50]   ok   5.35s  calls=2  in= 6325 (cache   24%)  out= 171  acum=$0.5121
#       [44/50]   ok   8.82s  calls=4  in=30423 (cache   59%)  out= 279  acum=$0.5529
#       [45/50]   ok   9.73s  calls=3  in=12705 (cache   44%)  out= 427  acum=$0.5730
#       [46/50]   ok   7.37s  calls=4  in=14186 (cache   61%)  out= 158  acum=$0.5923
#       [47/50]   ok   4.81s  calls=2  in= 6099 (cache   25%)  out= 172  acum=$0.6017
#       [48/50]   ok   3.78s  calls=2  in= 5753 (cache   29%)  out= 120  acum=$0.6101
#       [49/50]   ok   7.38s  calls=2  in= 5606 (cache   30%)  out= 318  acum=$0.6203
#       [50/50]   ok   7.17s  calls=2  in= 5953 (cache   28%)  out= 268  acum=$0.6304
#        ✓ ok — salvo em petrobras__openai__gpt-5.4__20260430_144830.xlsx
#
# [run]  anthropic/claude-sonnet-4-6 × bndes (id=1)
#       [ 1/50]   ok  11.02s  calls=2  in=10611 (cache   23%)  out= 489  acum=$0.0392
#       [ 2/50]   ok    8.4s  calls=2  in= 9851 (cache   49%)  out= 339  acum=$0.0738
#       [ 3/50]   ok   7.47s  calls=2  in= 9639 (cache   50%)  out= 280  acum=$0.1069
#       [ 4/50]   ok  11.57s  calls=2  in= 9836 (cache   49%)  out= 499  acum=$0.1439
#       [ 5/50]   ok   8.72s  calls=2  in=10843 (cache   45%)  out= 366  acum=$0.1819
#       [ 6/50]   ok  13.71s  calls=2  in=10737 (cache   45%)  out= 660  acum=$0.2240
#       [ 7/50]   ok  11.22s  calls=2  in=10785 (cache   45%)  out= 576  acum=$0.2650
#       [ 8/50]   ok   11.0s  calls=2  in= 9649 (cache   50%)  out= 466  acum=$0.3010
#       [ 9/50]   ok  11.47s  calls=3  in=21915 (cache   33%)  out= 475  acum=$0.3738
#       [10/50]   ok  11.37s  calls=2  in=10175 (cache   48%)  out= 512  acum=$0.4121
#       [11/50]   ok    8.5s  calls=2  in=10168 (cache   48%)  out= 316  acum=$0.4473
#       [12/50]   ok  10.65s  calls=2  in=10591 (cache   46%)  out= 539  acum=$0.4872
#       [13/50]   ok  11.47s  calls=2  in=11112 (cache   44%)  out= 510  acum=$0.5281
#       [14/50]   ok  11.78s  calls=2  in=10177 (cache   48%)  out= 645  acum=$0.5683
#       [15/50]   ok  10.91s  calls=3  in=25678 (cache   28%)  out= 408  acum=$0.6515
#       [16/50]   ok   9.37s  calls=2  in=10637 (cache   46%)  out= 409  acum=$0.6895
#       [17/50]   ok   21.2s  calls=3  in=25962 (cache   28%)  out= 949  acum=$0.7817
#       [18/50]   ok  13.41s  calls=2  in=10551 (cache   46%)  out= 787  acum=$0.8251
#       [19/50]   ok   9.42s  calls=2  in=11187 (cache   43%)  out= 396  acum=$0.8646
#       [20/50]   ok   6.76s  calls=2  in=10182 (cache   48%)  out= 284  acum=$0.8994
#       [21/50]   ok  19.86s  calls=2  in=10551 (cache   46%)  out= 950  acum=$0.9453
#       [22/50]   ok  14.64s  calls=2  in= 9704 (cache   50%)  out= 822  acum=$0.9868
#       [23/50]   ok  10.95s  calls=2  in= 9969 (cache   49%)  out= 506  acum=$1.0243
#       [24/50]   ok   12.1s  calls=2  in= 9595 (cache   50%)  out= 523  acum=$1.0609
#       [25/50]   ok   5.62s  calls=2  in=10268 (cache   47%)  out= 192  acum=$1.0946
#       [26/50]   ok  21.09s  calls=6  in=64033 (cache   42%)  out= 791  acum=$1.2986
#       [27/50]   ok  20.48s  calls=7  in=93346 (cache   47%)  out= 766  acum=$1.5901
#       [28/50]   ok  13.45s  calls=2  in=10731 (cache   45%)  out= 564  acum=$1.6307
#       [29/50]   ok   7.24s  calls=2  in=10025 (cache   48%)  out= 284  acum=$1.6651
#       [30/50]   ok  20.79s  calls=4  in=38500 (cache   26%)  out=1112  acum=$1.7972
#       [31/50]   ok  10.34s  calls=2  in=11085 (cache   44%)  out= 480  acum=$1.8377
#       [32/50]   ok  10.65s  calls=2  in=11135 (cache   43%)  out= 486  acum=$1.8784
#       [33/50]   ok  12.29s  calls=2  in=10479 (cache   46%)  out= 491  acum=$1.9172
#       [34/50]   ok   7.68s  calls=2  in=11385 (cache   43%)  out= 320  acum=$1.9562
#       [35/50]   ok  10.44s  calls=2  in=11009 (cache   44%)  out= 521  acum=$1.9970
#       [36/50]   ok  12.19s  calls=2  in=10435 (cache   46%)  out= 620  acum=$2.0376
#       [37/50]   ok  16.79s  calls=2  in=11673 (cache   41%)  out= 921  acum=$2.0864
#       [38/50]   ok   12.6s  calls=2  in=12081 (cache   40%)  out= 598  acum=$2.1316
#       [39/50]   ok  14.85s  calls=3  in=25717 (cache   28%)  out= 563  acum=$2.2172
#       [40/50]   ok  14.64s  calls=2  in=11633 (cache   42%)  out= 745  acum=$2.2633
#       [41/50]   ok  18.12s  calls=2  in=11657 (cache   42%)  out= 944  acum=$2.3125
#       [42/50]   ok   7.47s  calls=2  in=11324 (cache   43%)  out= 306  acum=$2.3510
#       [43/50]   ok  10.86s  calls=2  in=11511 (cache   42%)  out= 448  acum=$2.3923
#       [44/50]   ok   13.1s  calls=2  in=11506 (cache   42%)  out= 541  acum=$2.4349
#       [45/50]   ok  19.35s  calls=2  in=10580 (cache   46%)  out=1072  acum=$2.4827
#       [46/50]   ok   7.89s  calls=2  in=10158 (cache   48%)  out= 353  acum=$2.5185
#       [47/50]   ok  17.92s  calls=2  in=10200 (cache   47%)  out= 682  acum=$2.5593
#       [48/50]   ok   6.66s  calls=2  in=10785 (cache   45%)  out= 233  acum=$2.5952
#       [49/50]   ok  23.24s  calls=2  in=10805 (cache   45%)  out= 924  acum=$2.6414
#       [50/50]   ok  16.39s  calls=2  in=10437 (cache   46%)  out= 770  acum=$2.6843
#        ✓ ok — salvo em bndes__anthropic__claude-sonnet-4-6__20260430_145859.xlsx
#
# [run]  anthropic/claude-sonnet-4-6 × cvm (id=2)
#       [ 1/50]   ok   7.47s  calls=2  in= 9680 (cache   25%)  out= 348  acum=$0.0343
#       [ 2/50]   ok    7.7s  calls=2  in= 9386 (cache   52%)  out= 260  acum=$0.0663
#       [ 3/50]   ok   8.64s  calls=2  in=10152 (cache   48%)  out= 345  acum=$0.1019
#       [ 4/50]   ok  11.78s  calls=2  in= 9410 (cache   51%)  out= 531  acum=$0.1381
#       [ 5/50]   ok   9.47s  calls=2  in= 9417 (cache   51%)  out= 433  acum=$0.1729
#       [ 6/50]   ok  13.05s  calls=2  in= 9080 (cache   53%)  out= 574  acum=$0.2087
#       [ 7/50]   ok  12.39s  calls=2  in= 9750 (cache   50%)  out= 593  acum=$0.2469
#       [ 8/50]   ok  13.56s  calls=2  in= 9959 (cache   49%)  out= 481  acum=$0.2840
#       [ 9/50]   ok   8.66s  calls=2  in= 8650 (cache   56%)  out= 280  acum=$0.3141
#       [10/50]   ok   9.53s  calls=2  in= 9289 (cache   52%)  out= 422  acum=$0.3483
#       [11/50]   ok   8.59s  calls=2  in= 9738 (cache   50%)  out= 362  acum=$0.3830
#       [12/50]   ok  12.08s  calls=2  in= 9807 (cache   49%)  out= 527  acum=$0.4203
#       [13/50]   ok   8.22s  calls=2  in= 9527 (cache   51%)  out= 327  acum=$0.4538
#       [14/50]   ok  11.24s  calls=2  in= 9087 (cache   53%)  out= 479  acum=$0.4882
#       [15/50]   ok    9.5s  calls=2  in= 9307 (cache   52%)  out= 419  acum=$0.5224
#       [16/50]   ok  20.69s  calls=4  in=36174 (cache   28%)  out= 916  acum=$0.6447
#       [17/50]   ok  19.48s  calls=2  in= 9492 (cache   51%)  out= 400  acum=$0.6792
#       [18/50]   ok  18.26s  calls=2  in=11424 (cache   42%)  out= 821  acum=$0.7258
#       [19/50]   ok   7.17s  calls=2  in=10339 (cache   47%)  out= 291  acum=$0.7611
#       [20/50]   ok    7.5s  calls=2  in=11122 (cache   44%)  out= 329  acum=$0.7994
#       [21/50]   ok  17.41s  calls=2  in= 9540 (cache   51%)  out= 861  acum=$0.8410
#       [22/50]   ok  15.68s  calls=2  in= 9594 (cache   50%)  out= 806  acum=$0.8818
#       [23/50]   ok   8.09s  calls=2  in= 9936 (cache   49%)  out= 339  acum=$0.9167
#       [24/50]   ok    8.5s  calls=2  in=10268 (cache   47%)  out= 342  acum=$0.9527
#       [25/50]   ok  26.72s  calls=7  in=69988 (cache   57%)  out= 909  acum=$1.1763
#       [26/50]   ok   7.36s  calls=2  in=10711 (cache   45%)  out= 244  acum=$1.2121
#       [27/50]   ok  11.78s  calls=2  in=10927 (cache   44%)  out= 488  acum=$1.2522
#       [28/50]   ok  19.36s  calls=2  in=10192 (cache   48%)  out= 733  acum=$1.2937
#       [29/50]   ok   8.91s  calls=2  in=10610 (cache   46%)  out= 365  acum=$1.3310
#       [30/50]   ok  14.53s  calls=4  in=31066 (cache   33%)  out= 671  acum=$1.4343
#       [31/50]   ok  13.84s  calls=2  in= 9505 (cache   51%)  out= 696  acum=$1.4733
#       [32/50]   ok  14.13s  calls=2  in= 9605 (cache   50%)  out= 522  acum=$1.5099
#       [33/50]   ok   9.78s  calls=2  in= 9592 (cache   50%)  out= 476  acum=$1.5458
#       [34/50]   ok   5.58s  calls=2  in= 9270 (cache   52%)  out= 178  acum=$1.5763
#       [35/50]   ok   9.53s  calls=2  in= 9268 (cache   52%)  out= 456  acum=$1.6109
#       [36/50]   ok   9.01s  calls=2  in= 9304 (cache   52%)  out= 397  acum=$1.6448
#       [37/50]   ok  15.56s  calls=2  in=11548 (cache   42%)  out= 762  acum=$1.6909
#       [38/50]   ok  17.38s  calls=4  in=37714 (cache   27%)  out= 829  acum=$1.8165
#       [39/50]   ok  12.32s  calls=2  in= 9593 (cache   50%)  out= 526  acum=$1.8531
#       [40/50]   ok  21.09s  calls=2  in=10903 (cache   44%)  out= 667  acum=$1.8958
#       [41/50]   ok  20.99s  calls=2  in=10912 (cache   44%)  out= 963  acum=$1.9430
#       [42/50]   ok   7.68s  calls=2  in= 9546 (cache   51%)  out= 310  acum=$1.9763
#       [43/50]   ok   6.48s  calls=2  in= 9653 (cache   50%)  out= 302  acum=$2.0098
#       [44/50]   ok  11.95s  calls=2  in=10860 (cache   45%)  out= 490  acum=$2.0497
#       [45/50]   ok  26.05s  calls=5  in=59670 (cache   31%)  out=1408  acum=$2.2499
#       [46/50]   ok   10.1s  calls=2  in=10749 (cache   45%)  out= 474  acum=$2.2892
#       [47/50]   ok  11.67s  calls=2  in= 8765 (cache   55%)  out= 552  acum=$2.3238
#       [48/50]   ok  11.01s  calls=2  in= 9113 (cache   53%)  out= 456  acum=$2.3580
#       [49/50]   ok  20.32s  calls=2  in= 9237 (cache   52%)  out= 908  acum=$2.3993
#       [50/50]   ok  16.63s  calls=2  in= 9149 (cache   53%)  out= 724  acum=$2.4376
#        ✓ ok — salvo em cvm__anthropic__claude-sonnet-4-6__20260430_150934.xlsx
#
# [run]  anthropic/claude-sonnet-4-6 × petrobras (id=3)
#       [ 1/50]   ok   9.75s  calls=2  in=10920 (cache   22%)  out= 416  acum=$0.0390
#       [ 2/50]   ok   7.48s  calls=2  in= 9407 (cache   52%)  out= 297  acum=$0.0717
#       [ 3/50]   ok   9.93s  calls=2  in=10983 (cache   44%)  out= 344  acum=$0.1098
#       [ 4/50]   ok  10.03s  calls=2  in= 9675 (cache   50%)  out= 440  acum=$0.1454
#       [ 5/50]   ok   9.14s  calls=2  in=10822 (cache   45%)  out= 357  acum=$0.1832
#       [ 6/50]   ok  16.15s  calls=2  in=10768 (cache   45%)  out= 751  acum=$0.2268
#       [ 7/50]   ok  13.52s  calls=2  in=11019 (cache   44%)  out= 579  acum=$0.2685
#       [ 8/50]   ok   13.0s  calls=2  in=10979 (cache   44%)  out= 502  acum=$0.3090
#       [ 9/50]   ok  12.28s  calls=2  in= 9720 (cache   50%)  out= 519  acum=$0.3460
#       [10/50]   ok  11.27s  calls=2  in=10007 (cache   49%)  out= 476  acum=$0.3831
#       [11/50]   ok   8.12s  calls=2  in= 9759 (cache   50%)  out= 325  acum=$0.4173
#       [12/50]   ok  11.13s  calls=2  in= 9755 (cache   50%)  out= 583  acum=$0.4553
#       [13/50]   ok  10.96s  calls=2  in=11637 (cache   42%)  out= 411  acum=$0.4964
#       [14/50]   ok  14.34s  calls=2  in=10150 (cache   48%)  out= 682  acum=$0.5370
#       [15/50]   ok  20.89s  calls=6  in=91071 (cache   30%)  out= 768  acum=$0.8218
#       [16/50]   ok  12.49s  calls=2  in=11929 (cache   41%)  out= 529  acum=$0.8655
#       [17/50]   ok  26.42s  calls=4  in=37497 (cache   27%)  out=1182  acum=$0.9957
#       [18/50]   ok  16.28s  calls=2  in=10403 (cache   47%)  out= 734  acum=$1.0379
#       [19/50]   ok   8.09s  calls=2  in=10324 (cache   47%)  out= 372  acum=$1.0745
#       [20/50]   ok   7.27s  calls=2  in=10422 (cache   47%)  out= 302  acum=$1.1103
#       [21/50]   ok  16.38s  calls=2  in= 9425 (cache   52%)  out= 813  acum=$1.1507
#       [22/50]   ok  18.81s  calls=2  in= 9198 (cache   53%)  out= 848  acum=$1.1911
#       [23/50]   ok   11.6s  calls=2  in= 9841 (cache   49%)  out= 510  acum=$1.2282
#       [24/50]   ok  12.24s  calls=2  in=10079 (cache   48%)  out= 574  acum=$1.2671
#       [25/50]   ok   19.3s  calls=5  in=53046 (cache   35%)  out= 835  acum=$1.4387
#       [26/50]   ok   8.34s  calls=2  in=10679 (cache   46%)  out= 400  acum=$1.4768
#       [27/50]   ok  17.36s  calls=5  in=50976 (cache   34%)  out= 619  acum=$1.6390
#       [28/50]   ok  16.28s  calls=2  in=10056 (cache   48%)  out= 736  acum=$1.6802
#       [29/50]   ok  18.63s  calls=5  in=56354 (cache   32%)  out= 787  acum=$1.8611
#       [30/50]   ok  11.27s  calls=2  in=10005 (cache   49%)  out= 613  acum=$1.9003
#       [31/50]   ok  11.98s  calls=2  in= 9523 (cache   51%)  out= 611  acum=$1.9380
#       [32/50]   ok  10.55s  calls=2  in= 9701 (cache   50%)  out= 545  acum=$1.9753
#       [33/50]   ok  12.08s  calls=2  in= 9863 (cache   49%)  out= 535  acum=$2.0129
#       [34/50]   ok   9.93s  calls=2  in= 9574 (cache   51%)  out= 408  acum=$2.0477
#       [35/50]   ok   9.21s  calls=2  in=10484 (cache   46%)  out= 464  acum=$2.0862
#       [36/50]   ok  11.68s  calls=2  in= 9932 (cache   49%)  out= 499  acum=$2.1234
#       [37/50]   ok  24.98s  calls=3  in=24155 (cache   30%)  out=1370  acum=$2.2165
#       [38/50]   ok  11.43s  calls=2  in= 9555 (cache   51%)  out= 524  acum=$2.2530
#       [39/50]   ok   15.3s  calls=2  in= 9619 (cache   51%)  out= 661  acum=$2.2918
#       [40/50]   ok  11.67s  calls=2  in=11623 (cache   42%)  out= 521  acum=$2.3344
#       [41/50]   ok  22.12s  calls=3  in=24983 (cache   29%)  out=1080  acum=$2.4256
#       [42/50]   ok   9.42s  calls=2  in=10790 (cache   45%)  out= 299  acum=$2.4624
#       [43/50]   ok    8.6s  calls=2  in=11286 (cache   43%)  out= 332  acum=$2.5013
#       [44/50]   ok  18.64s  calls=5  in=50723 (cache   36%)  out= 737  acum=$2.6645
#       [45/50]   ok  21.09s  calls=3  in=22741 (cache   32%)  out=1010  acum=$2.7479
#       [46/50]   ok   9.62s  calls=2  in=11810 (cache   41%)  out= 346  acum=$2.7885
#       [47/50]   ok  12.08s  calls=2  in=10695 (cache   45%)  out= 593  acum=$2.8295
#       [48/50]   ok  10.14s  calls=2  in= 9921 (cache   49%)  out= 334  acum=$2.8642
#       [49/50]   ok  16.89s  calls=2  in=10050 (cache   48%)  out= 737  acum=$2.9055
#       [50/50]   ok  17.82s  calls=2  in= 9925 (cache   49%)  out= 761  acum=$2.9466
#        ✓ ok — salvo em petrobras__anthropic__claude-sonnet-4-6__20260430_152048.xlsx
#
# [run]  anthropic/claude-opus-4-7 × bndes (id=1)
#       [ 1/50]   ok   9.07s  calls=2  in=13570 (cache   24%)  out= 487  acum=$0.0800
#       [ 2/50]   ok    8.7s  calls=2  in=13178 (cache   49%)  out= 373  acum=$0.1552
#       [ 3/50]   ok   5.63s  calls=2  in=12543 (cache   51%)  out= 236  acum=$0.2239
#       [ 4/50]   ok   9.32s  calls=2  in=12865 (cache   50%)  out= 454  acum=$0.2995
#       [ 5/50]   ok  10.07s  calls=2  in=14043 (cache   46%)  out= 542  acum=$0.3833
#       [ 6/50]   ok  15.39s  calls=2  in=15070 (cache   43%)  out= 869  acum=$0.4804
#       [ 7/50]   ok   7.62s  calls=2  in=13872 (cache   46%)  out= 396  acum=$0.5596
#       [ 8/50]   ok   8.29s  calls=2  in=12895 (cache   50%)  out= 391  acum=$0.6339
#       [ 9/50]   ok  31.01s  calls=4  in=52728 (cache   25%)  out=1199  acum=$0.9275
#       [10/50]   ok  23.57s  calls=4  in=53970 (cache   25%)  out=1156  acum=$1.2262
#       [11/50]   ok  11.84s  calls=2  in=13690 (cache   47%)  out= 448  acum=$1.3059
#       [12/50]   ok   15.5s  calls=2  in=13875 (cache   46%)  out= 681  acum=$1.3923
#       [13/50]   ok   6.76s  calls=2  in=14308 (cache   45%)  out= 284  acum=$1.4709
#       [14/50]   ok  11.26s  calls=2  in=12952 (cache   50%)  out= 500  acum=$1.5482
#       [15/50]   ok  12.65s  calls=3  in=30493 (cache   32%)  out= 539  acum=$1.7141
#       [16/50]   ok   9.26s  calls=2  in=13590 (cache   47%)  out= 427  acum=$1.7928
#       [17/50]   ok  24.47s  calls=4  in=52150 (cache   26%)  out=1255  acum=$2.0849
#       [18/50]   ok   8.87s  calls=2  in=14039 (cache   46%)  out= 546  acum=$2.1687
#       [19/50]   ok    7.0s  calls=2  in=13400 (cache   48%)  out= 322  acum=$2.2438
#       [20/50]   ok  11.06s  calls=3  in=30939 (cache   31%)  out= 518  acum=$2.4114
#       [21/50]   ok  16.49s  calls=2  in=13860 (cache   47%)  out= 927  acum=$2.5039
#       [22/50]   ok  13.72s  calls=2  in=12966 (cache   50%)  out= 836  acum=$2.5896
#       [23/50]   ok   7.51s  calls=2  in=14277 (cache   45%)  out= 369  acum=$2.6702
#       [24/50]   ok  12.46s  calls=2  in=12951 (cache   50%)  out= 582  acum=$2.7495
#       [25/50]   ok   5.22s  calls=2  in=13831 (cache   47%)  out= 187  acum=$2.8234
#       [26/50]   ok   6.86s  calls=2  in=14207 (cache   45%)  out= 324  acum=$2.9025
#       [27/50]   ok  12.18s  calls=3  in=30627 (cache   32%)  out= 582  acum=$3.0702
#       [28/50]   ok  17.62s  calls=2  in=14576 (cache   44%)  out= 898  acum=$3.1655
#       [29/50]   ok   6.24s  calls=2  in=13342 (cache   48%)  out= 240  acum=$3.2382
#       [30/50]   ok  15.44s  calls=2  in=14263 (cache   45%)  out= 800  acum=$3.3296
#       [31/50]   ok  12.72s  calls=2  in=13722 (cache   47%)  out= 646  acum=$3.4143
#       [32/50]   ok   8.91s  calls=2  in=13288 (cache   49%)  out= 448  acum=$3.4920
#       [33/50]   ok   9.42s  calls=2  in=12906 (cache   50%)  out= 518  acum=$3.5694
#       [34/50]   ok   5.12s  calls=2  in=14510 (cache   44%)  out= 190  acum=$3.6467
#       [35/50]   ok  10.24s  calls=2  in=14500 (cache   44%)  out= 527  acum=$3.7324
#       [36/50]   ok   7.06s  calls=2  in=13596 (cache   47%)  out= 330  acum=$3.8086
#       [37/50]   ok  15.82s  calls=2  in=15378 (cache   42%)  out= 939  acum=$3.9090
#       [38/50]   ok  12.76s  calls=2  in=15301 (cache   42%)  out= 636  acum=$4.0014
#       [39/50]   ok  10.45s  calls=2  in=14235 (cache   45%)  out= 477  acum=$4.0845
#       [40/50]   ok  13.62s  calls=2  in=15556 (cache   41%)  out= 640  acum=$4.1783
#       [41/50]   ok  17.82s  calls=2  in=16474 (cache   39%)  out= 906  acum=$4.2833
#       [42/50]   ok   7.48s  calls=2  in=14280 (cache   45%)  out= 298  acum=$4.3622
#       [43/50]   ok  10.24s  calls=2  in=15039 (cache   43%)  out= 427  acum=$4.4480
#       [44/50]   ok  18.23s  calls=3  in=32096 (cache   30%)  out= 871  acum=$4.6303
#       [45/50]   ok  23.04s  calls=3  in=33418 (cache   29%)  out=1368  acum=$4.8316
#       [46/50]   ok   7.17s  calls=2  in=14825 (cache   43%)  out= 339  acum=$4.9142
#       [47/50]   ok  11.57s  calls=2  in=14936 (cache   43%)  out= 558  acum=$5.0028
#       [48/50]   ok   6.45s  calls=2  in=14411 (cache   45%)  out= 267  acum=$5.0815
#       [49/50]   ok  20.17s  calls=2  in=15470 (cache   42%)  out=1034  acum=$5.1847
#       [50/50]   ok  14.54s  calls=2  in=12063 (cache   53%)  out= 689  acum=$5.2623
#        ✓ ok — salvo em bndes__anthropic__claude-opus-4-7__20260430_153052.xlsx
#
# [run]  anthropic/claude-opus-4-7 × cvm (id=2)
#       [ 1/50]   ok   7.95s  calls=2  in=13092 (cache   25%)  out= 357  acum=$0.0744
#       [ 2/50]   ok   9.83s  calls=2  in=12607 (cache   51%)  out= 377  acum=$0.1468
#       [ 3/50]   ok   7.99s  calls=2  in=13076 (cache   49%)  out= 328  acum=$0.2204
#       [ 4/50]   ok  10.85s  calls=2  in=12364 (cache   52%)  out= 547  acum=$0.2959
#       [ 5/50] ERRO   2.67s  calls=1  in= 3691 (cache   87%)  out= 112  acum=$0.3172
#       [ 6/50] ERRO   0.25s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [ 7/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [ 8/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [ 9/50] ERRO   0.23s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [10/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [11/50] ERRO   0.24s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [12/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [13/50] ERRO   0.23s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [14/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [15/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [16/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [17/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [18/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [19/50] ERRO   0.23s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [20/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [21/50] ERRO   0.18s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [22/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [23/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [24/50] ERRO   0.23s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [25/50] ERRO   0.23s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [26/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [27/50] ERRO   0.18s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [28/50] ERRO   0.23s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [29/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [30/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [31/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [32/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [33/50] ERRO   0.36s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [34/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [35/50] ERRO   0.18s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [36/50] ERRO    0.4s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [37/50] ERRO   0.24s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [38/50] ERRO   0.21s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [39/50] ERRO   0.26s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [40/50] ERRO   0.23s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [41/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [42/50] ERRO   0.39s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [43/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [44/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [45/50] ERRO   0.23s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [46/50] ERRO   0.21s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [47/50] ERRO   0.18s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [48/50] ERRO   0.23s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [49/50] ERRO   0.17s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#       [50/50] ERRO   0.23s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.3172
#        ✓ ok — salvo em cvm__anthropic__claude-opus-4-7__20260430_153141.xlsx
#
# [run]  anthropic/claude-opus-4-7 × petrobras (id=3)
#       [ 1/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [ 2/50] ERRO   0.23s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [ 3/50] ERRO   0.19s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [ 4/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [ 5/50] ERRO   0.24s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [ 6/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [ 7/50] ERRO   0.18s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [ 8/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [ 9/50] ERRO   0.24s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [10/50] ERRO   0.23s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [11/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [12/50] ERRO   0.17s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [13/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [14/50] ERRO   0.46s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [15/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [16/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [17/50] ERRO   0.18s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [18/50] ERRO   0.23s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [19/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [20/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [21/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [22/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [23/50] ERRO   1.78s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [24/50] ERRO   0.18s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [25/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [26/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [27/50] ERRO   0.17s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [28/50] ERRO   0.38s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [29/50] ERRO   0.19s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [30/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [31/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [32/50] ERRO   0.18s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [33/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [34/50] ERRO   0.23s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [35/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [36/50] ERRO   0.18s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [37/50] ERRO   0.28s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [38/50] ERRO   0.17s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [39/50] ERRO   0.24s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [40/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [41/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [42/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [43/50] ERRO   0.23s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [44/50] ERRO   0.22s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [45/50] ERRO   0.24s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [46/50] ERRO   0.23s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [47/50] ERRO   0.18s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [48/50] ERRO    0.2s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [49/50] ERRO   0.24s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#       [50/50] ERRO   0.23s  calls=0  in=    0 (cache    0%)  out=   0  acum=$0.0000
#        ✓ ok — salvo em petrobras__anthropic__claude-opus-4-7__20260430_153154.xlsx
#
# [run]  openai/gpt-5.5 × bndes (id=1)
#       [ 1/50]   ok  10.12s  calls=3  in= 8837 (cache    0%)  out= 212  acum=$0.0505
#       [ 2/50]   ok   5.84s  calls=2  in= 7336 (cache    0%)  out=  97  acum=$0.0901
#       [ 3/50]   ok   8.89s  calls=3  in=11767 (cache   32%)  out= 204  acum=$0.1551
#       [ 4/50]   ok  22.44s  calls=2  in= 7175 (cache    0%)  out= 184  acum=$0.1965
#       [ 5/50]   ok  16.96s  calls=4  in=20089 (cache   24%)  out= 614  acum=$0.3154
#       [ 6/50]   ok   6.49s  calls=2  in= 7204 (cache    0%)  out= 229  acum=$0.3582
#       [ 7/50]   ok  13.72s  calls=3  in= 9141 (cache    0%)  out= 244  acum=$0.4113
#       [ 8/50]   ok   7.27s  calls=2  in= 6501 (cache    0%)  out= 146  acum=$0.4481
#       [ 9/50]   ok  14.13s  calls=3  in=14273 (cache    0%)  out= 461  acum=$0.5333
#       [10/50]   ok   9.86s  calls=2  in= 7100 (cache    0%)  out= 229  acum=$0.5757
#       [11/50]   ok   9.08s  calls=2  in= 4840 (cache    0%)  out= 148  acum=$0.6044
#       [12/50]   ok  12.39s  calls=2  in= 6653 (cache    0%)  out= 222  acum=$0.6443
#       [13/50]   ok  26.61s  calls=3  in= 8671 (cache    0%)  out= 500  acum=$0.7026
#       [14/50]   ok  17.83s  calls=2  in= 6906 (cache    0%)  out= 194  acum=$0.7430
#       [15/50]   ok  37.13s  calls=3  in=14353 (cache   26%)  out= 238  acum=$0.8219
#       [16/50]   ok  25.54s  calls=2  in= 7188 (cache    0%)  out= 186  acum=$0.8634
#       [17/50]   ok  54.27s  calls=4  in=19900 (cache    0%)  out=1028  acum=$0.9938
#       [18/50]   ok  21.41s  calls=2  in= 7205 (cache    0%)  out= 281  acum=$1.0382
#       [19/50]   ok  18.64s  calls=2  in= 7471 (cache    0%)  out= 162  acum=$1.0804
#       [20/50]   ok  19.86s  calls=2  in= 7219 (cache    0%)  out= 136  acum=$1.1206
#       [21/50]   ok  21.58s  calls=2  in= 7182 (cache    0%)  out= 258  acum=$1.1642
#       [22/50]   ok  34.75s  calls=3  in=17179 (cache    0%)  out= 486  acum=$1.2647
#       [23/50]   ok  20.89s  calls=2  in= 6731 (cache    0%)  out= 168  acum=$1.3034
#       [24/50]   ok  24.68s  calls=2  in= 6412 (cache    0%)  out= 195  acum=$1.3413
#       [25/50]   ok  38.09s  calls=2  in= 6907 (cache    0%)  out= 117  acum=$1.3794
#       [26/50]   ok  31.54s  calls=3  in=18266 (cache    0%)  out= 269  acum=$1.4788
#       [27/50]   ok  30.68s  calls=3  in=17074 (cache    0%)  out= 233  acum=$1.5711
#       [28/50]   ok  24.51s  calls=2  in= 6250 (cache    0%)  out= 289  acum=$1.6111
#       [29/50]   ok  18.23s  calls=2  in= 7114 (cache    0%)  out= 123  acum=$1.6503
#       [30/50]   ok  20.15s  calls=2  in= 7399 (cache    0%)  out= 233  acum=$1.6943
#       [31/50]   ok  17.63s  calls=2  in= 7360 (cache    0%)  out= 231  acum=$1.7380
#       [32/50]   ok  29.49s  calls=2  in= 7660 (cache    0%)  out= 184  acum=$1.7818
#       [33/50]   ok  23.34s  calls=2  in= 6414 (cache    0%)  out= 143  acum=$1.8182
#       [34/50]   ok  25.91s  calls=2  in= 7545 (cache    0%)  out= 106  acum=$1.8591
#       [35/50]   ok  19.56s  calls=2  in= 8095 (cache    0%)  out= 185  acum=$1.9051
#       [36/50]   ok  28.45s  calls=2  in= 7336 (cache    0%)  out= 189  acum=$1.9475
#       [37/50]   ok  44.05s  calls=3  in=18427 (cache    0%)  out= 722  acum=$2.0613
#       [38/50]   ok  31.81s  calls=3  in=13624 (cache    0%)  out= 268  acum=$2.1374
#       [39/50]   ok  33.24s  calls=3  in=13866 (cache    0%)  out= 389  acum=$2.2184
#       [40/50]   ok  23.83s  calls=2  in= 7318 (cache    0%)  out= 171  acum=$2.2602
#       [41/50]   ok  20.89s  calls=2  in= 7659 (cache    0%)  out= 432  acum=$2.3114
#       [42/50]   ok  22.63s  calls=2  in= 7327 (cache    0%)  out= 107  acum=$2.3513
#       [43/50]   ok  20.28s  calls=2  in= 7446 (cache    0%)  out= 123  acum=$2.3922
#       [44/50]   ok  22.63s  calls=2  in= 7989 (cache    0%)  out= 365  acum=$2.4431
#       [45/50]   ok  18.28s  calls=2  in= 7264 (cache    0%)  out= 411  acum=$2.4917
#       [46/50]   ok  14.07s  calls=2  in= 7393 (cache    0%)  out= 183  acum=$2.5342
#       [47/50]   ok   17.0s  calls=2  in= 6749 (cache    0%)  out= 213  acum=$2.5743
#       [48/50]   ok  14.64s  calls=2  in= 4542 (cache    0%)  out= 106  acum=$2.6002
#       [49/50]   ok  13.72s  calls=2  in= 7245 (cache    0%)  out= 276  acum=$2.6447
#       [50/50]   ok   17.0s  calls=2  in= 6294 (cache    0%)  out= 245  acum=$2.6835
#        ✓ ok — salvo em bndes__openai__gpt-5.5__20260430_154956.xlsx
#
# [run]  openai/gpt-5.5 × cvm (id=2)
#       [ 1/50]   ok  21.16s  calls=3  in= 8692 (cache    0%)  out= 200  acum=$0.0495
#       [ 2/50]   ok  14.64s  calls=2  in= 6603 (cache    0%)  out=  91  acum=$0.0852
#       [ 3/50]   ok  14.33s  calls=2  in= 5809 (cache    0%)  out= 104  acum=$0.1174
#       [ 4/50]   ok  19.15s  calls=2  in= 6379 (cache    0%)  out= 207  acum=$0.1555
#       [ 5/50]   ok  28.98s  calls=3  in= 8444 (cache    0%)  out= 371  acum=$0.2088
#       [ 6/50]   ok  15.05s  calls=2  in= 6144 (cache    0%)  out= 269  acum=$0.2476
#       [ 7/50]   ok  15.57s  calls=2  in= 6529 (cache    0%)  out= 125  acum=$0.2840
#       [ 8/50]   ok  14.23s  calls=2  in= 5224 (cache    0%)  out= 135  acum=$0.3142
#       [ 9/50]   ok  14.64s  calls=2  in= 6234 (cache    0%)  out= 166  acum=$0.3503
#       [10/50]   ok  13.41s  calls=2  in= 5948 (cache    0%)  out= 181  acum=$0.3855
#       [11/50]   ok  13.52s  calls=2  in= 6523 (cache    0%)  out= 132  acum=$0.4221
#       [12/50]   ok  15.24s  calls=2  in= 6258 (cache    0%)  out= 121  acum=$0.4570
#       [13/50]   ok  19.99s  calls=3  in= 8060 (cache    0%)  out= 231  acum=$0.5042
#       [14/50]   ok  11.57s  calls=2  in= 6366 (cache    0%)  out= 184  acum=$0.5416
#       [15/50]   ok   17.1s  calls=2  in= 4821 (cache    0%)  out= 120  acum=$0.5693
#       [16/50]   ok  11.16s  calls=2  in= 7043 (cache    0%)  out= 168  acum=$0.6095
#       [17/50]   ok  29.64s  calls=3  in=13809 (cache    0%)  out= 913  acum=$0.7060
#       [18/50]   ok  13.13s  calls=2  in= 6946 (cache    0%)  out= 176  acum=$0.7460
#       [19/50]   ok  14.37s  calls=2  in= 6882 (cache    0%)  out= 146  acum=$0.7848
#       [20/50]   ok  13.52s  calls=2  in= 7006 (cache    0%)  out= 140  acum=$0.8240
#       [21/50]   ok  16.59s  calls=2  in= 6230 (cache    0%)  out= 224  acum=$0.8619
#       [22/50]   ok  16.18s  calls=2  in= 6676 (cache    0%)  out= 231  acum=$0.9022
#       [23/50]   ok  13.72s  calls=2  in= 6247 (cache    0%)  out= 135  acum=$0.9375
#       [24/50]   ok  25.29s  calls=3  in=13978 (cache    0%)  out= 278  acum=$1.0157
#       [25/50]   ok  57.04s  calls=6  in=45002 (cache    0%)  out=1050  acum=$1.2722
#       [26/50]   ok  23.86s  calls=3  in=12386 (cache    0%)  out= 265  acum=$1.3421
#       [27/50]   ok  24.21s  calls=3  in=16712 (cache    0%)  out= 409  acum=$1.4379
#       [28/50]   ok  15.73s  calls=2  in= 7124 (cache    0%)  out= 281  acum=$1.4820
#       [29/50]   ok  25.39s  calls=3  in=17421 (cache    0%)  out= 471  acum=$1.5832
#       [30/50]   ok  14.44s  calls=2  in= 6970 (cache    0%)  out= 268  acum=$1.6261
#       [31/50]   ok  10.17s  calls=2  in= 6332 (cache    0%)  out= 169  acum=$1.6628
#       [32/50]   ok  12.94s  calls=2  in= 6231 (cache    0%)  out= 197  acum=$1.6999
#       [33/50]   ok   16.6s  calls=2  in= 6454 (cache    0%)  out= 119  acum=$1.7357
#       [34/50]   ok   8.62s  calls=2  in= 6415 (cache    0%)  out=  95  acum=$1.7706
#       [35/50]   ok   17.1s  calls=2  in= 6542 (cache    0%)  out= 186  acum=$1.8089
#       [36/50]   ok  32.87s  calls=2  in= 6695 (cache    0%)  out= 223  acum=$1.8491
#       [37/50]   ok   17.0s  calls=2  in= 7719 (cache    0%)  out= 277  acum=$1.8960
#       [38/50]   ok  15.26s  calls=2  in= 6516 (cache    0%)  out= 173  acum=$1.9338
#       [39/50]   ok   17.2s  calls=2  in= 6225 (cache    0%)  out= 311  acum=$1.9742
#       [40/50]   ok  16.28s  calls=2  in= 7252 (cache    0%)  out= 229  acum=$2.0174
#       [41/50]   ok  20.93s  calls=2  in= 7344 (cache    0%)  out= 389  acum=$2.0658
#       [42/50]   ok  15.69s  calls=2  in= 6545 (cache    0%)  out= 145  acum=$2.1028
#       [43/50]   ok  21.34s  calls=2  in= 6217 (cache    0%)  out= 130  acum=$2.1378
#       [44/50]   ok  19.45s  calls=2  in= 6817 (cache    0%)  out= 145  acum=$2.1763
#       [45/50]   ok  30.37s  calls=3  in=15128 (cache    0%)  out= 611  acum=$2.2702
#       [46/50]   ok  15.71s  calls=2  in= 7218 (cache    0%)  out= 263  acum=$2.3142
#       [47/50]   ok  17.71s  calls=2  in= 6533 (cache    0%)  out= 260  acum=$2.3547
#       [48/50]   ok  16.71s  calls=2  in= 6087 (cache    0%)  out= 158  acum=$2.3898
#       [49/50]   ok  17.71s  calls=2  in= 5769 (cache    0%)  out= 305  acum=$2.4278
#       [50/50]   ok  22.22s  calls=2  in= 6162 (cache    0%)  out= 433  acum=$2.4716
#        ✓ ok — salvo em cvm__openai__gpt-5.5__20260430_160521.xlsx
#
# [run]  openai/gpt-5.5 × petrobras (id=3)
#       [ 1/50]   ok  46.54s  calls=5  in=22129 (cache   21%)  out= 269  acum=$0.1187
#       [ 2/50]   ok  17.41s  calls=2  in= 6719 (cache    0%)  out=  91  acum=$0.1550
#       [ 3/50]   ok  17.41s  calls=2  in= 6650 (cache    0%)  out= 116  acum=$0.1918
#       [ 4/50]   ok  18.43s  calls=2  in= 6428 (cache    0%)  out= 178  acum=$0.2293
#       [ 5/50]   ok  22.33s  calls=3  in= 9083 (cache    0%)  out= 302  acum=$0.2837
#       [ 6/50]   ok  14.64s  calls=2  in= 7358 (cache    0%)  out= 247  acum=$0.3279
#       [ 7/50]   ok  24.58s  calls=3  in= 9026 (cache    0%)  out= 252  acum=$0.3806
#       [ 8/50]   ok  20.58s  calls=2  in= 6864 (cache    0%)  out= 189  acum=$0.4206
#       [ 9/50]   ok  21.19s  calls=2  in= 6099 (cache    0%)  out= 216  acum=$0.4576
#       [10/50]   ok  17.92s  calls=2  in= 6789 (cache    0%)  out= 134  acum=$0.4955
#       [11/50]   ok  18.95s  calls=2  in= 4620 (cache    0%)  out= 112  acum=$0.5220
#       [12/50]   ok  18.43s  calls=2  in= 6882 (cache    0%)  out= 208  acum=$0.5627
#       [13/50]   ok  35.43s  calls=3  in= 8178 (cache    0%)  out= 442  acum=$0.6168
#       [14/50]   ok  18.02s  calls=2  in= 6567 (cache    0%)  out= 206  acum=$0.6558
#       [15/50]   ok  31.13s  calls=3  in=18568 (cache    0%)  out= 188  acum=$0.7543
#       [16/50]   ok  24.17s  calls=2  in= 6822 (cache    0%)  out= 161  acum=$0.7932
#       [17/50]   ok   55.5s  calls=5  in=36971 (cache   37%)  out= 845  acum=$1.0034
#       [18/50]   ok  23.45s  calls=2  in= 6252 (cache    0%)  out= 225  acum=$1.0415
#       [19/50]   ok  19.87s  calls=2  in= 6871 (cache    0%)  out= 159  acum=$1.0806
#       [20/50]   ok  16.17s  calls=2  in= 6473 (cache    0%)  out= 134  acum=$1.1170
#       [21/50]   ok  22.47s  calls=2  in= 6285 (cache    0%)  out= 308  acum=$1.1576
#       [22/50]   ok  21.15s  calls=2  in= 6259 (cache    0%)  out= 320  acum=$1.1985
#       [23/50]   ok  22.46s  calls=2  in= 6369 (cache    0%)  out= 148  acum=$1.2348
#       [24/50]   ok   21.0s  calls=2  in= 5825 (cache    0%)  out= 220  acum=$1.2705
#       [25/50]   ok  50.02s  calls=4  in=30140 (cache    0%)  out= 534  acum=$1.4373
#       [26/50]   ok  24.07s  calls=2  in= 7910 (cache    0%)  out= 172  acum=$1.4820
#       [27/50]   ok  20.48s  calls=2  in= 6447 (cache    0%)  out= 140  acum=$1.5184
#       [28/50]   ok  20.68s  calls=2  in= 6642 (cache    0%)  out= 257  acum=$1.5593
#       [29/50]   ok  25.28s  calls=2  in= 6587 (cache    0%)  out= 297  acum=$1.6012
#       [30/50]   ok  21.31s  calls=2  in= 6397 (cache    0%)  out= 222  acum=$1.6398
#       [31/50]   ok  22.73s  calls=2  in= 6452 (cache    0%)  out= 204  acum=$1.6782
#       [32/50]   ok  41.74s  calls=4  in=21688 (cache   31%)  out= 497  acum=$1.8015
#       [33/50]   ok  15.91s  calls=2  in= 6679 (cache    0%)  out= 136  acum=$1.8390
#       [34/50]   ok  22.12s  calls=2  in= 6318 (cache    0%)  out= 141  acum=$1.8748
#       [35/50]   ok  22.42s  calls=2  in= 7191 (cache    0%)  out= 172  acum=$1.9160
#       [36/50]   ok  20.21s  calls=2  in= 6831 (cache    0%)  out= 169  acum=$1.9552
#       [37/50]   ok  51.16s  calls=4  in=30780 (cache   15%)  out= 918  acum=$2.1366
#       [38/50]   ok  14.47s  calls=2  in= 6933 (cache    0%)  out= 205  acum=$2.1774
#       [39/50]   ok  17.69s  calls=2  in= 6376 (cache    0%)  out= 207  acum=$2.2155
#       [40/50]   ok  20.58s  calls=2  in= 8201 (cache    0%)  out= 209  acum=$2.2628
#       [41/50]   ok  23.24s  calls=2  in= 6975 (cache    0%)  out= 350  acum=$2.3082
#       [42/50]   ok  35.33s  calls=4  in=25441 (cache    0%)  out= 398  acum=$2.4473
#       [43/50]   ok  54.27s  calls=5  in=41817 (cache   63%)  out= 515  acum=$2.6719
#       [44/50]   ok  15.27s  calls=2  in= 6853 (cache    0%)  out= 327  acum=$2.7159
#       [45/50]   ok  19.91s  calls=3  in=17599 (cache    0%)  out= 572  acum=$2.8211
#       [46/50]   ok  10.49s  calls=3  in=13146 (cache    0%)  out= 261  acum=$2.8946
#       [47/50]   ok  11.06s  calls=2  in= 6463 (cache    0%)  out= 199  acum=$2.9329
#       [48/50]   ok  11.26s  calls=2  in= 5103 (cache    0%)  out= 154  acum=$2.9631
#       [49/50]   ok  16.63s  calls=2  in= 7207 (cache    0%)  out= 404  acum=$3.0112
#       [50/50]   ok  14.91s  calls=2  in= 6367 (cache    0%)  out= 387  acum=$3.0547
#        ✓ ok — salvo em petrobras__openai__gpt-5.5__20260430_162514.xlsx
#
# ============================================================
# === SUMÁRIO ===
# ============================================================
#
# ✓ Sucessos: 12
#     openai/gpt-5.4 × bndes  →  bndes__openai__gpt-5.4__20260430_143844.xlsx
#     openai/gpt-5.4 × cvm  →  cvm__openai__gpt-5.4__20260430_144346.xlsx
#     openai/gpt-5.4 × petrobras  →  petrobras__openai__gpt-5.4__20260430_144830.xlsx
#     anthropic/claude-sonnet-4-6 × bndes  →  bndes__anthropic__claude-sonnet-4-6__20260430_145859.xlsx
#     anthropic/claude-sonnet-4-6 × cvm  →  cvm__anthropic__claude-sonnet-4-6__20260430_150934.xlsx
#     anthropic/claude-sonnet-4-6 × petrobras  →  petrobras__anthropic__claude-sonnet-4-6__20260430_152048.xlsx
#     anthropic/claude-opus-4-7 × bndes  →  bndes__anthropic__claude-opus-4-7__20260430_153052.xlsx
#     anthropic/claude-opus-4-7 × cvm  →  cvm__anthropic__claude-opus-4-7__20260430_153141.xlsx
#     anthropic/claude-opus-4-7 × petrobras  →  petrobras__anthropic__claude-opus-4-7__20260430_153154.xlsx
#     openai/gpt-5.5 × bndes  →  bndes__openai__gpt-5.5__20260430_154956.xlsx
#     openai/gpt-5.5 × cvm  →  cvm__openai__gpt-5.5__20260430_160521.xlsx
#     openai/gpt-5.5 × petrobras  →  petrobras__openai__gpt-5.5__20260430_162514.xlsx
#
# ⚠ Parciais (estouro de orçamento): 0
#
# ✗ Falhas: 0

# %% [markdown]
# ## Sumário consolidado

# %%
import re

padrao_nome = re.compile(
    r"^(?P<edital>[^_]+)__(?P<provider>[^_]+)__(?P<modelo>.+?)__\d{8}_\d{6}(?:__PARCIAL)?\.xlsx$"
)

linhas = []
for arq in sorted(RESULTADOS_DIR.glob("*.xlsx")):
    m = padrao_nome.match(arq.name)
    if not m:
        continue
    df = pd.read_excel(arq)
    if "cache_read_tokens" not in df.columns:
        df["cache_read_tokens"] = 0
    if "custo_real_usd" not in df.columns:
        df["custo_real_usd"] = df["custo_usd"]

    linhas.append({
        "edital":           m["edital"],
        "provider":         m["provider"],
        "modelo":           m["modelo"],
        "n_perguntas":      len(df),
        "n_erros":          int(df["erro"].notna().sum()),
        "input_tokens":     int(df["input_tokens"].sum()),
        "output_tokens":    int(df["output_tokens"].sum()),
        "cache_read":       int(df["cache_read_tokens"].sum()),
        "cache_pct":        float(df["cache_read_tokens"].sum() / max(df["input_tokens"].sum(), 1)),
        "custo_estim_usd":  round(float(df["custo_usd"].sum()), 4),
        "custo_real_usd":   round(float(df["custo_real_usd"].sum()), 4),
        "latencia_med_s":   round(float(df["latencia_s"].mean()), 2),
        "latencia_p95_s":   round(float(df["latencia_s"].quantile(0.95)), 2),
        "arquivo":          arq.name,
    })

df_sumario = pd.DataFrame(linhas).sort_values(["edital", "custo_real_usd"]).reset_index(drop=True)
df_sumario["cache_pct"] = df_sumario["cache_pct"].map("{:.1%}".format)
df_sumario
# Out:
#        edital   provider             modelo  n_perguntas  n_erros  \
# 0       bndes   deepseek  deepseek-v4-flash           50        0
# 1       bndes     openai        gpt-4o-mini           50        0
# 2       bndes     openai       gpt-5.4-mini           50        0
# 3       bndes   deepseek    deepseek-v4-pro           50        0
# 4       bndes     openai            gpt-5.4           50        0
# 5       bndes  anthropic   claude-haiku-4-5           50        0
# 6       bndes     openai            gpt-5.5           50        0
# 7       bndes  anthropic  claude-sonnet-4-6           50        0
# 8       bndes  anthropic    claude-opus-4-7           50        0
# 9         cvm   deepseek  deepseek-v4-flash           50        0
# 10        cvm     openai        gpt-4o-mini           50        0
# 11        cvm     openai       gpt-5.4-mini           50        0
# 12        cvm   deepseek    deepseek-v4-pro           50        0
# 13        cvm  anthropic    claude-opus-4-7           50       46
# 14        cvm     openai            gpt-5.4           50        0
# 15        cvm  anthropic   claude-haiku-4-5           50        0
# 16        cvm  anthropic  claude-sonnet-4-6           50        0
# 17        cvm     openai            gpt-5.5           50        0
# 18  petrobras  anthropic    claude-opus-4-7           50       50
# 19  petrobras   deepseek  deepseek-v4-flash           50        0
# 20  petrobras     openai        gpt-4o-mini           50        0
# 21  petrobras     openai       gpt-5.4-mini           50        0
# 22  petrobras   deepseek    deepseek-v4-pro           50        0
# 23  petrobras     openai            gpt-5.4           50        0
# 24  petrobras  anthropic   claude-haiku-4-5           50        0
# 25  petrobras     openai            gpt-5.5           50        0
# 26  petrobras  anthropic  claude-sonnet-4-6           50        0
#
#     input_tokens  output_tokens  cache_read cache_pct  custo_estim_usd  \
# 0         651794          21562     1223680    187.7%           0.0973
# 1         423484           9378       60416     14.3%           0.0691
# 2         332401           8532       84864     25.5%           0.1002
# 3         681518          23169      772096    113.3%           1.2665
# 4         416440           8978      169472     40.7%           0.6103
# 5         700866          23247           0      0.0%           0.8171
# 6         457896          13135       12160      2.7%           2.6835
# 7         752603          28433      315931     42.0%           2.6843
# 8         905074          29476      355910     39.3%           5.2623
# 9         558979          19510      715264    128.0%           0.0837
# 10        433446           8765      145408     33.5%           0.0703
# 11        323919           8298       82816     25.6%           0.0976
# 12        601746          22188      707584    117.6%           1.1242
# 13         54830           1721       25800     47.1%           0.3172
# 14        406384           8802      166272     40.9%           0.5960
# 15        655949          21637           0      0.0%           0.7641
# 16        677578          26992      303784     44.8%           2.4376
# 17        418667          12610           0      0.0%           2.4716
# 18             0              0           0      0.0%           0.0000
# 19        782633          23279      985856    126.0%           0.1161
# 20        481300           9269      156288     32.5%           0.0778
# 21        393450           9109      110336     28.0%           0.1166
# 22        730046          26005      876288    120.0%           1.3608
# 23        432284           9003      166272     38.5%           0.6304
# 24        882385          24172           0      0.0%           1.0032
# 25        528630          13717       56320     10.7%           3.0547
# 26        833859          29671      328284     39.4%           2.9466
#
#     custo_real_usd  latencia_med_s  latencia_p95_s  \
# 0           0.0405            8.89           17.08
# 1           0.0646            5.45           10.38
# 2           0.0896            2.94            4.73
# 3           0.2201           17.69           33.55
# 4           0.5044            5.34            9.58
# 5           0.8171           15.57           35.46
# 6           2.6531           21.64           37.66
# 7           2.6843           12.58           20.95
# 8           5.2623           12.08           23.33
# 9           0.0262            7.82           13.25
# 10          0.0594            5.23            8.58
# 11          0.0872            2.72            4.32
# 12          0.1899           16.75           30.45
# 13          0.3172            0.99            7.97
# 14          0.4921            6.05           12.73
# 15          0.7641           15.80           36.02
# 16          2.4376           12.69           21.04
# 17          2.4716           18.49           30.04
# 18          0.0000            0.25            0.33
# 19          0.0359            8.97           18.94
# 20          0.0660            6.22            9.98
# 21          0.1028            3.17            5.41
# 22          0.2362           19.22           38.01
# 23          0.5265            5.67            9.50
# 24          1.0032           21.14           67.02
# 25          2.9139           23.85           50.65
# 26          2.9466           13.48           21.66
#
#                                               arquivo
# 0   bndes__deepseek__deepseek-v4-flash__20260429_2...
# 1    bndes__openai__gpt-4o-mini__20260429_231806.xlsx
# 2   bndes__openai__gpt-5.4-mini__20260429_235130.xlsx
# 3   bndes__deepseek__deepseek-v4-pro__20260430_001...
# 4        bndes__openai__gpt-5.4__20260430_143844.xlsx
# 5   bndes__anthropic__claude-haiku-4-5__20260430_0...
# 6        bndes__openai__gpt-5.5__20260430_154956.xlsx
# 7   bndes__anthropic__claude-sonnet-4-6__20260430_...
# 8   bndes__anthropic__claude-opus-4-7__20260430_15...
# 9   cvm__deepseek__deepseek-v4-flash__20260429_234...
# 10     cvm__openai__gpt-4o-mini__20260429_232228.xlsx
# 11    cvm__openai__gpt-5.4-mini__20260429_235347.xlsx
# 12  cvm__deepseek__deepseek-v4-pro__20260430_00250...
# 13  cvm__anthropic__claude-opus-4-7__20260430_1531...
# 14         cvm__openai__gpt-5.4__20260430_144346.xlsx
# 15  cvm__anthropic__claude-haiku-4-5__20260430_010...
# 16  cvm__anthropic__claude-sonnet-4-6__20260430_15...
# 17         cvm__openai__gpt-5.5__20260430_160521.xlsx
# 18  petrobras__anthropic__claude-opus-4-7__2026043...
# 19  petrobras__deepseek__deepseek-v4-flash__202604...
# 20  petrobras__openai__gpt-4o-mini__20260429_23273...
# 21  petrobras__openai__gpt-5.4-mini__20260429_2356...
# 22  petrobras__deepseek__deepseek-v4-pro__20260430...
# 23   petrobras__openai__gpt-5.4__20260430_144830.xlsx
# 24  petrobras__anthropic__claude-haiku-4-5__202604...
# 25   petrobras__openai__gpt-5.5__20260430_162514.xlsx
# 26  petrobras__anthropic__claude-sonnet-4-6__20260...

# %% [markdown]
# ## Tabela cruzada — custo real por modelo × edital

# %%
df_pivot = (
    df_sumario.assign(modelo_full=lambda d: d["provider"] + "/" + d["modelo"])
              .pivot_table(index="modelo_full", columns="edital",
                          values="custo_real_usd", aggfunc="last")
)
df_pivot["total"] = df_pivot.sum(axis=1)
df_pivot.sort_values("total")
# Out:
# edital                        bndes     cvm  petrobras   total
# modelo_full
# deepseek/deepseek-v4-flash   0.0405  0.0262     0.0359  0.1026
# openai/gpt-4o-mini           0.0646  0.0594     0.0660  0.1900
# openai/gpt-5.4-mini          0.0896  0.0872     0.1028  0.2796
# deepseek/deepseek-v4-pro     0.2201  0.1899     0.2362  0.6462
# openai/gpt-5.4               0.5044  0.4921     0.5265  1.5230
# anthropic/claude-haiku-4-5   0.8171  0.7641     1.0032  2.5844
# anthropic/claude-opus-4-7    5.2623  0.3172     0.0000  5.5795
# openai/gpt-5.5               2.6531  2.4716     2.9139  8.0386
# anthropic/claude-sonnet-4-6  2.6843  2.4376     2.9466  8.0685

# %%
import pandas as pd, glob
from pathlib import Path

PRECOS = {
    "deepseek-v4-flash": (0.14, 0.028, 0.28),
    "deepseek-v4-pro":   (1.74, 0.145, 3.48),
}

def custo_real(in_tok, out_tok, cache_read, p_in, p_in_c, p_out):
    miss = max(in_tok - cache_read, 0)
    return miss/1e6*p_in + cache_read/1e6*p_in_c + out_tok/1e6*p_out

PASTA = "resultados"  # ajuste se rodar de outro cwd

for arq in sorted(glob.glob(f"{PASTA}/*deepseek*.xlsx")):
    if "__corrigido" in arq:
        continue
    df = pd.read_excel(arq)
    modelo = "deepseek-v4-flash" if "flash" in arq else "deepseek-v4-pro"
    p_in, p_in_c, p_out = PRECOS[modelo]

    # backup do que estava bugado
    df["cache_read_tokens__bug"] = df["cache_read_tokens"]
    df["custo_real_usd__bug"]    = df["custo_real_usd"]

    # correção: cache não pode ser maior que input
    df["cache_read_tokens"] = df["cache_read_tokens"].clip(upper=df["input_tokens"]).astype(int)
    df["cache_miss_tokens"] = (df["input_tokens"] - df["cache_read_tokens"]).astype(int)
    df["custo_real_usd"] = df.apply(
        lambda r: custo_real(r["input_tokens"], r["output_tokens"], r["cache_read_tokens"],
                             p_in, p_in_c, p_out), axis=1
    ).round(6)

    saida = arq.replace(".xlsx", "__corrigido.xlsx")
    df.to_excel(saida, index=False)
    print(f"{Path(saida).name}  ${df['custo_real_usd__bug'].sum():.4f} -> ${df['custo_real_usd'].sum():.4f}")
# Out:
# bndes__deepseek__deepseek-v4-flash__20260429_233504__corrigido.xlsx  $0.0405 -> $0.0244
# bndes__deepseek__deepseek-v4-pro__20260430_001110__corrigido.xlsx  $0.2201 -> $0.2047
# cvm__deepseek__deepseek-v4-flash__20260429_234135__corrigido.xlsx  $0.0262 -> $0.0217
# cvm__deepseek__deepseek-v4-pro__20260430_002507__corrigido.xlsx  $0.1899 -> $0.1738
# petrobras__deepseek__deepseek-v4-flash__20260429_234903__corrigido.xlsx  $0.0359 -> $0.0298
# petrobras__deepseek__deepseek-v4-pro__20260430_004108__corrigido.xlsx  $0.2362 -> $0.2135
