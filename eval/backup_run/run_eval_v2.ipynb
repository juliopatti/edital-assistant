# %% [markdown]
# # Avaliação do Agente — versão multi-provider
#
# Mesma estrutura do `run_eval.ipynb` original, mas com captura de tokens
# **provider-agnóstica** via callback manual. Funciona para OpenAI, Anthropic,
# Google e qualquer outro provider langchain que popule `usage_metadata`.
#
# Defaults: **anthropic / claude-haiku-4-5** + edital BNDES.

# %%
import os, sys, time
from pathlib import Path
from datetime import datetime

ROOT = Path.cwd().parent
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

import warnings
warnings.filterwarnings("ignore")
os.environ["TOKENIZERS_PARALLELISM"] = "false"

import pandas as pd
from dotenv import load_dotenv
load_dotenv(ROOT / ".env")

from agent.agent import build_agent, ask
from langchain_core.callbacks import BaseCallbackHandler

print(f"cwd:  {Path.cwd()}")
print(f"root: {ROOT}")
# Out:
# cwd:  /home/julio/Documentos/tcc_GENAI/v8/edital-assistant/evals
# root: /home/julio/Documentos/tcc_GENAI/v8/edital-assistant

# %% [markdown]
# ## TokenTracker — callback provider-agnóstico
#
# Registra `input_tokens` e `output_tokens` de toda invocação LLM dentro de seu
# escopo. Lê primeiro `llm_output.token_usage` (formato antigo, OpenAI-style) e
# fallback para `message.usage_metadata` (formato novo, Anthropic/Google/etc).

# %%
class TokenTracker(BaseCallbackHandler):
    def __init__(self):
        self.reset()

    def reset(self):
        self.input_tokens = 0
        self.output_tokens = 0
        self.n_calls = 0

    def on_llm_end(self, response, **kwargs):
        self.n_calls += 1

        # 1. formato antigo (langchain-openai): llm_output.token_usage
        usage = (getattr(response, "llm_output", None) or {}).get("token_usage") or {}
        if usage:
            self.input_tokens  += usage.get("prompt_tokens", 0) or 0
            self.output_tokens += usage.get("completion_tokens", 0) or 0
            return

        # 2. formato novo (padrão LangChain): message.usage_metadata
        for gen_list in response.generations:
            for gen in gen_list:
                msg = getattr(gen, "message", None)
                um = getattr(msg, "usage_metadata", None) if msg else None
                if um:
                    self.input_tokens  += um.get("input_tokens", 0) or 0
                    self.output_tokens += um.get("output_tokens", 0) or 0
                    break

# %% [markdown]
# ## Configuração

# %%
EDITAIS = {
    "bndes":     1,
    "cvm":       2,
    "petrobras": 3,
}

EDITAL_NOME = "bndes"
PROVIDER    = "anthropic"
MODEL       = "claude-haiku-4-5"

# preço em USD por 1M de tokens (input, output)
PRECOS = {
    "openai/gpt-4o-mini":             (0.15,  0.60),
    "openai/gpt-5.4-mini":            (0.25,  2.00),
    "openai/gpt-5.4":                 (1.25, 10.00),
    "openai/gpt-5.5":                 (5.00, 30.00),
    "google/gemini-2.5-flash-lite":   (0.10,  0.40),
    "google/gemini-3-flash-preview":  (0.30,  2.50),
    "google/gemini-3.1-pro-preview":  (1.50, 10.00),
    "anthropic/claude-haiku-4-5":     (1.00,  5.00),
    "anthropic/claude-sonnet-4-6":    (3.00, 15.00),
    "anthropic/claude-opus-4-7":      (5.00, 25.00),
}

EDITAL_ID = EDITAIS[EDITAL_NOME]
ARQ_PERGUNTAS = Path("perguntas") / f"{EDITAL_NOME}.xlsx"
PRECO_IN, PRECO_OUT = PRECOS[f"{PROVIDER}/{MODEL}"]

print(f"Edital:    {EDITAL_NOME} (id={EDITAL_ID})")
print(f"Modelo:    {PROVIDER}/{MODEL}")
print(f"Preço:     ${PRECO_IN}/M input  ${PRECO_OUT}/M output")
print(f"Perguntas: {ARQ_PERGUNTAS}")
# Out:
# Edital:    bndes (id=1)
# Modelo:    anthropic/claude-haiku-4-5
# Preço:     $1.0/M input  $5.0/M output
# Perguntas: perguntas/bndes.xlsx

# %% [markdown]
# ## Carregar perguntas

# %%
df_q = pd.read_excel(ARQ_PERGUNTAS)
df_q = df_q.dropna(subset=["pergunta"])
df_q = df_q[df_q["pergunta"].str.strip() != ""].reset_index(drop=True)
print(f"{len(df_q)} perguntas carregadas")
df_q.head()
# Out:
# 50 perguntas carregadas
#    id                  categoria  \
# 0   1  Dados sobre as inscrições
# 1   2  Dados sobre as inscrições
# 2   3  Dados sobre as inscrições
# 3   4  Dados sobre as inscrições
# 4   5  Dados sobre as inscrições
#
#                                             pergunta
# 0  Qual o período de inscrição para o concurso BN...
# 1  Qual o valor da taxa de inscrição do concurso ...
# 2  Em qual site o candidato deve fazer a inscriçã...
# 3  Quais são as formas de pagamento da taxa de in...
# 4  Qual é o prazo-limite de pagamento da inscriçã...

# %% [markdown]
# ## Construir agente + anexar tracker
#
# `with_config(callbacks=[tracker])` injeta o tracker nas invocações dos dois
# LLMs do agente (o principal com tools e o do self-check). Não modifica
# `agent.py` — atua via config dinâmica.

# %%
agente = build_agent(provider=PROVIDER, model=MODEL)

tracker = TokenTracker()
agente.llm       = agente.llm.with_config(callbacks=[tracker])
agente.llm_check = agente.llm_check.with_config(callbacks=[tracker])

print(f"Agente: {PROVIDER}/{MODEL}")
print(f"Tracker anexado em llm e llm_check")
# Out:
# Agente: anthropic/claude-haiku-4-5
# Tracker anexado em llm e llm_check

# %% [markdown]
# ## Rodar as 50 perguntas
#
# `chat_history=[]` em todas as chamadas → memória off. Tracker é zerado antes
# de cada pergunta para isolar o consumo do turno.

# %%
resultados = []

for i, row in df_q.iterrows():
    pergunta = row["pergunta"]
    t0 = time.time()
    erro = None
    resposta = None

    tracker.reset()
    try:
        resposta = ask(
            agent=agente,
            question=pergunta,
            chat_history=[],
            edital_id_ativo=EDITAL_ID,
        )
    except Exception as e:
        erro = str(e)

    in_tok    = tracker.input_tokens
    out_tok   = tracker.output_tokens
    n_calls   = tracker.n_calls
    custo_usd = in_tok / 1_000_000 * PRECO_IN + out_tok / 1_000_000 * PRECO_OUT
    latencia  = round(time.time() - t0, 2)

    resultados.append({
        "id":            row["id"],
        "categoria":     row.get("categoria", ""),
        "pergunta":      pergunta,
        "resposta":      resposta,
        "input_tokens":  in_tok,
        "output_tokens": out_tok,
        "total_tokens":  in_tok + out_tok,
        "n_invocacoes":  n_calls,
        "custo_usd":     round(custo_usd, 6),
        "latencia_s":    latencia,
        "erro":          erro,
    })

    flag = "ERRO" if erro else "ok"
    print(f"[{i+1:>2}/{len(df_q)}] {flag:>4}  {latencia:>5}s  "
          f"calls={n_calls}  in={in_tok:>5}  out={out_tok:>4}")

df_r = pd.DataFrame(resultados)
print(f"\n{len(df_r)} respostas coletadas")
# Out:
# Carregando BGE-M3 (primeira vez pode demorar)...
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights: 100%|██████████| 391/391 [00:00<00:00, 36593.47it/s]
# [ 1/50]   ok   9.55s  calls=2  in=10951  out= 308
# [ 2/50]   ok   4.85s  calls=2  in=10440  out= 367
# [ 3/50]   ok   3.84s  calls=2  in=10079  out= 258
# [ 4/50]   ok   9.83s  calls=2  in=10304  out= 362
# [ 5/50]   ok   5.96s  calls=2  in=11284  out= 446
# [ 6/50]   ok   6.84s  calls=2  in=11076  out= 557
# [ 7/50]   ok   4.61s  calls=2  in=11078  out= 362
# [ 8/50]   ok   5.32s  calls=2  in=10318  out= 388
# [ 9/50]   ok   29.8s  calls=4  in=41603  out= 791
# [10/50]   ok  23.25s  calls=2  in=10635  out= 439
# [11/50]   ok  13.21s  calls=2  in=10511  out= 276
# [12/50]   ok  10.65s  calls=2  in=10972  out= 489
# [13/50]   ok  14.85s  calls=2  in=11420  out= 342
# [14/50]   ok  15.97s  calls=2  in=10785  out= 560
# [15/50]   ok  12.29s  calls=2  in=11580  out= 455
# [16/50]   ok   12.5s  calls=2  in=10684  out= 449
# [17/50]   ok   12.8s  calls=2  in=10746  out= 561
# [18/50]   ok  14.23s  calls=2  in=10938  out= 560
# [19/50]   ok   9.22s  calls=2  in=11579  out= 387
# [20/50]   ok  36.56s  calls=4  in=29454  out= 523
# [21/50]   ok  14.85s  calls=2  in=10933  out= 538
# [22/50]   ok  14.23s  calls=2  in=10045  out= 681
# [23/50]   ok  10.75s  calls=2  in=10229  out= 394
# [24/50]   ok  13.31s  calls=2  in= 9782  out= 470
# [25/50]   ok   8.09s  calls=2  in=11865  out= 181
# [26/50]   ok  27.86s  calls=3  in=25031  out= 524
# [27/50]   ok  59.91s  calls=5  in=50405  out= 769
# [28/50]   ok  21.71s  calls=2  in=10879  out= 623
# [29/50]   ok   9.63s  calls=2  in=10417  out= 277
# [30/50]   ok  26.54s  calls=3  in=23591  out= 675
# [31/50]   ok  15.24s  calls=2  in=11461  out= 361
# [32/50]   ok  13.51s  calls=2  in=12334  out= 416
# [33/50]   ok  15.46s  calls=2  in=10864  out= 320
# [34/50]   ok  11.26s  calls=2  in=11576  out= 220
# [35/50]   ok  17.31s  calls=2  in=12013  out= 444
# [36/50]   ok  14.64s  calls=2  in=11951  out= 491
# [37/50]   ok  13.41s  calls=2  in=12190  out= 662
# [38/50]   ok   13.0s  calls=2  in=12465  out= 381
# [39/50]   ok  15.56s  calls=2  in=11572  out= 407
# [40/50]   ok  14.34s  calls=2  in=12024  out= 539
# [41/50]   ok  16.48s  calls=2  in=13339  out= 710
# [42/50]   ok  12.19s  calls=2  in=11727  out= 284
# [43/50]   ok  16.69s  calls=2  in=11899  out= 303
# [44/50]   ok  12.13s  calls=2  in=12239  out= 395
# [45/50]   ok  17.77s  calls=2  in=11331  out= 731
# [46/50]   ok  11.57s  calls=2  in=10453  out= 305
# [47/50]   ok   12.5s  calls=2  in=10548  out= 500
# [48/50]   ok  11.88s  calls=2  in=11489  out= 323
# [49/50]   ok  16.49s  calls=2  in=11392  out= 648
# [50/50]   ok  13.11s  calls=2  in= 9676  out= 539
#
# 50 respostas coletadas

# %% [markdown]
# ## Salvar

# %%
ts = datetime.now().strftime("%Y%m%d_%H%M%S")
slug_modelo = MODEL.replace("/", "_").replace(":", "_")
nome_base = f"{EDITAL_NOME}__{PROVIDER}__{slug_modelo}__{ts}"

Path("resultados").mkdir(exist_ok=True)
arq = Path("resultados") / f"{nome_base}.xlsx"
df_r.to_excel(arq, index=False)
print(f"Salvo: {arq}")
# Out:
# Salvo: resultados/bndes__anthropic__claude-haiku-4-5__20260429_043654.xlsx

# %% [markdown]
# ## Sumário

# %%
total_in   = int(df_r["input_tokens"].sum())
total_out  = int(df_r["output_tokens"].sum())
total_cost = float(df_r["custo_usd"].sum())
n_erros    = int(df_r["erro"].notna().sum())
lat_media  = float(df_r["latencia_s"].mean())
lat_p95    = float(df_r["latencia_s"].quantile(0.95))
calls_med  = float(df_r["n_invocacoes"].mean())

print(f"Perguntas:        {len(df_r)}  ({n_erros} com erro)")
print(f"Tokens entrada:   {total_in:,}")
print(f"Tokens saída:     {total_out:,}")
print(f"Tokens totais:    {total_in + total_out:,}")
print(f"Custo medido:     US$ {total_cost:.4f}   ({PROVIDER}/{MODEL})")
print(f"Latência média:   {lat_media:.1f}s")
print(f"Latência p95:     {lat_p95:.1f}s")
print(f"Invocações médias por pergunta: {calls_med:.1f}")
# Out:
# Perguntas:        50  (0 com erro)
# Tokens entrada:   672,157
# Tokens saída:     22,991
# Tokens totais:    695,148
# Custo medido:     US$ 0.7871   (anthropic/claude-haiku-4-5)
# Latência média:   15.0s
# Latência p95:     28.9s
# Invocações médias por pergunta: 2.2

# %% [markdown]
# ## Extrapolação para os outros modelos
#
# A partir dos tokens medidos **agora** (com o tokenizer deste modelo),
# estima o custo dos outros. Tokenizers diferem entre providers — números
# reais podem variar ~10–35%.

# %%
linhas = []
for nome, (pi, po) in PRECOS.items():
    custo_1ed = total_in / 1_000_000 * pi + total_out / 1_000_000 * po
    linhas.append({
        "modelo":              nome,
        "preco_in_usd_p_1M":   pi,
        "preco_out_usd_p_1M":  po,
        "custo_50q_1edital":   round(custo_1ed, 4),
        "custo_50q_3editais":  round(custo_1ed * 3, 4),
    })

df_custos = (
    pd.DataFrame(linhas)
    .sort_values("custo_50q_1edital")
    .reset_index(drop=True)
)
df_custos
# Out:
#                           modelo  preco_in_usd_p_1M  preco_out_usd_p_1M  \
# 0   google/gemini-2.5-flash-lite               0.10                 0.4
# 1             openai/gpt-4o-mini               0.15                 0.6
# 2            openai/gpt-5.4-mini               0.25                 2.0
# 3  google/gemini-3-flash-preview               0.30                 2.5
# 4     anthropic/claude-haiku-4-5               1.00                 5.0
# 5                 openai/gpt-5.4               1.25                10.0
# 6  google/gemini-3.1-pro-preview               1.50                10.0
# 7    anthropic/claude-sonnet-4-6               3.00                15.0
# 8      anthropic/claude-opus-4-7               5.00                25.0
# 9                 openai/gpt-5.5               5.00                30.0
#
#    custo_50q_1edital  custo_50q_3editais
# 0             0.0764              0.2292
# 1             0.1146              0.3439
# 2             0.2140              0.6421
# 3             0.2591              0.7774
# 4             0.7871              2.3613
# 5             1.0701              3.2103
# 6             1.2381              3.7144
# 7             2.3613              7.0840
# 8             3.9356             11.8067
# 9             4.0505             12.1515

# %% [markdown]
# ## Inspecionar respostas

# %%
for _, row in df_r.head(5).iterrows():
    print(f"--- Q{int(row['id'])} ---")
    print(f"P: {row['pergunta']}")
    print(f"R: {row['resposta']}")
    print(f"   tokens={row['total_tokens']}  calls={row['n_invocacoes']}  latencia={row['latencia_s']}s\n")
# Out:
# --- Q1 ---
# P: Qual o período de inscrição para o concurso BNDES?
# R: **Período de inscrição do BNDES (01/2024):**
#
# O período de inscrição foi de **26 de julho a 19 de agosto de 2024**, com inscrições realizadas entre **10h do dia 26/07 e 23h59 do dia 19/08/2024** na página da Fundação Cesgranrio (www.cesgranrio.org.br).
#
# **Status atual:** Hoje é **29/04/2026**. O período de inscrição **já encerrou** há mais de um ano e meio. Este concurso não está mais aberto para novas inscrições.
#
# ref: edital [6.2.1, 6.3.1, ANEXO III]
#    tokens=11259  calls=2  latencia=9.55s
#
# --- Q2 ---
# P: Qual o valor da taxa de inscrição do concurso BNDES?
# R: A **taxa de inscrição do concurso BNDES é de R$ 110,00 (cento e dez reais)**.
#
# O pagamento pode ser feito de duas formas:
# 1. **Boleto Bancário** — em qualquer banco até a data de vencimento
# 2. **Cobrança PIX** — usando a opção "Copia e Cola" ou QR Code gerado
#
# **Pontos importantes:**
# - A inscrição só é válida após a confirmação do pagamento até a data de vencimento
# - O pagamento após a data de vencimento implica cancelamento da inscrição
# - O valor não é devolvido, exceto em caso de cancelamento do certame ou pagamento em duplicidade
# - Existem isenções para candidatos amparados pela Lei nº 13.656/2018 (doadores de medula óssea) e para inscritos no Cadastro Único
#
# ref: edital [6.2.3, 6.3.2, 6.2.5, 6.6]
#    tokens=10807  calls=2  latencia=4.85s
#
# --- Q3 ---
# P: Em qual site o candidato deve fazer a inscrição do concurso BNDES?
# R: O candidato deve fazer a inscrição no **site da Fundação Cesgranrio** (www.cesgranrio.org.br).
#
# A inscrição é realizada **exclusivamente via internet**, no período entre **10 horas do dia 26/07 e 23h59 do dia 19/08/2024**. No sistema eletrônico, o candidato deve escolher o cargo/ênfase e a cidade de realização das provas, além de pagar a taxa de inscrição de R$ 110,00.
#
# ref: edital [6.2.1, 6.3.1]
#    tokens=10337  calls=2  latencia=3.84s
#
# --- Q4 ---
# P: Quais são as formas de pagamento da taxa de inscrição do concurso BNDES?
# R: Com base no edital do BNDES, as formas de pagamento da taxa de inscrição são **duas**:
#
# 1. **Boleto Bancário** — você pode efetuar o pagamento em qualquer banco até a data de vencimento constante no boleto.
#
# 2. **Cobrança PIX** — utilizando a opção "Copia e Cola" ou QR Code gerado no valor da inscrição.
#
# **Pontos importantes:**
# - O pagamento deve ser realizado até a data de vencimento. Pagamentos após essa data implicam o cancelamento da inscrição.
# - **Não são aceitos** pagamentos por depósito/transferência bancária, chaves PIX (CNPJ), e-mail, telefone ou agência/conta.
# - A inscrição só será válida após a confirmação do pagamento.
# - O valor da taxa é **R$ 110,00** (cento e dez reais).
#
# ref: edital [6.3.2, 6.2.3]
#    tokens=10666  calls=2  latencia=9.83s
#
# --- Q5 ---
# P: Qual é o prazo-limite de pagamento da inscrição do concurso BNDES?
# R: Com base no edital do BNDES, o **prazo-limite de pagamento da inscrição é a data de vencimento do boleto bancário ou do PIX gerado no sistema**.
#
# Especificamente:
#
# - **Período de inscrição**: 26/07 a 19/08/2024
# - **Forma de pagamento**: Boleto Bancário ou Cobrança PIX
# - **Prazo limite**: O pagamento deve ser realizado **até a data de vencimento constante no boleto** ou no PIX gerado no sistema de inscrição
# - **Consequência do atraso**: O pagamento após a data de vencimento implica o **cancelamento automático da inscrição**
#
# O edital também orienta que, em caso de feriado ou fechamento de agências bancárias, o candidato deve antecipar o pagamento ou realizá-lo por outro meio válido, respeitando sempre o prazo limite determinado.
#
# **Importante**: A inscrição só será válida após a confirmação do pagamento até a data do vencimento. Não são aceitos pagamentos por depósito/transferência bancária ou por chaves PIX (CNPJ), e-mail, telefone ou agência/conta.
#
# ref: edital [6.3.2]
#    tokens=11730  calls=2  latencia=5.96s
